# %%
# !pip install gdown
# !gdown --id '1ZHiWbLZvraM6tyZx4s9ZuNT1IvjxHb-3' --output Face.zip
# !unzip Face.zip

# %%
# !git clone https://github.com/kipr/opencv

# %%
# !pip install transformers==4.5.0

# %%
import numpy as np

import torch
import torchvision
from torchvision.transforms import transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import ConcatDataset, DataLoader
from torchvision.datasets import DatasetFolder, ImageFolder

from transformers import get_linear_schedule_with_warmup

# %%
def crop_face(tensor_img):
  img = np.asarray(transforms.ToPILImage()(tensor_img))
  faces = face_cascade.detectMultiScale(image = img, scaleFactor = 1.01, minNeighbors = 3)

  if len(faces) > 1:
    max_area, index = 0,0
    for i in range(len(faces)):
      if faces[i][2]*faces[i][3] > max_area:
        max_area, index = faces[i][2]*faces[i][3], i
    faces = np.expand_dims(faces[index], axis=0)

  for (x, y, w, h) in faces:
      cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 0), -1)
      
  return torch.tensor(img).permute(2, 0, 1)

# %%
import cv2

face_cascade = cv2.CascadeClassifier('./opencv/data/haarcascades/haarcascade_frontalface_default.xml')

img = cv2.imread('./Face/A_Face/A_cropped/1563164911-9bd7b2224cec3f3a154b52247dfd6c83-696x463_cropped.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_RGB2BGR))
plt.axis("off")
plt.show()

faces = face_cascade.detectMultiScale(image = img, scaleFactor = 1.1, minNeighbors = 7)

for (x, y, w, h) in faces:
      cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 0), -1)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_RGB2BGR)) 
plt.axis("off")
plt.show()

# %%
train_tfm = transforms.Compose([
    transforms.Resize((64,64)),
    transforms.ToTensor(),
])

train_flip_tfm = transforms.Compose([
    transforms.RandomHorizontalFlip(p=1),
    transforms.Resize((64,64)),
    transforms.ToTensor(),
])

addition_tfm = transforms.Compose([
    torchvision.transforms.RandomAffine(degrees=30, shear=(0,15))
])

# %%
A_train_set = ImageFolder("./Face/A_Face", loader=lambda x: Image.open(x), transform=train_tfm)
A_train_flip_set = ImageFolder("./Face/A_Face", loader=lambda x: Image.open(x), transform=train_flip_tfm)
A_train_set = ConcatDataset([A_train_set, A_train_flip_set])
A_train_loader = DataLoader(A_train_set, batch_size=1, shuffle=True, pin_memory=True, num_workers=2)

# %%
len(A_train_loader)
# Out:
# 102

# %%
fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(transforms.ToPILImage()(A_train_set[i][0]))
  plt.xticks([])
  plt.yticks([])

# %%
fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(transforms.ToPILImage()(crop_face(A_train_set[i][0])))
  plt.xticks([])
  plt.yticks([])

# %%
B_train_set = ImageFolder("./Face/B_Face", loader=lambda x: Image.open(x), transform=train_tfm)
B_train_flip_set = ImageFolder("./Face/B_Face", loader=lambda x: Image.open(x), transform=train_flip_tfm)
B_train_set = ConcatDataset([B_train_set, B_train_flip_set])
B_train_loader = DataLoader(B_train_set, batch_size=1, shuffle=True, pin_memory=True, num_workers=2)

# %%
len(B_train_loader)
# Out:
# 102

# %%
fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(transforms.ToPILImage()(B_train_set[i][0]))
  plt.xticks([])
  plt.yticks([])

# %%
fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(transforms.ToPILImage()(crop_face(B_train_set[i][0])))
  plt.xticks([])
  plt.yticks([])

# %%
torch.random.manual_seed(6)
plt.imshow(transforms.ToPILImage()(addition_tfm(crop_face(B_train_set[0][0]))))
plt.show()
torch.random.manual_seed(6)
plt.imshow(transforms.ToPILImage()(addition_tfm(B_train_set[0][0])))
plt.show()

# %%
class conv_autoencoder(nn.Module):
    def __init__(self):
        super(conv_autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 512, 4, stride=2, padding=1), 
            nn.Dropout(0.2),
            nn.ReLU(),
            nn.Conv2d(512, 1024, 4, stride=2, padding=1), 
            nn.Dropout(0.2),  
            nn.ReLU(),
            nn.Conv2d(1024, 2048, 4, stride=2, padding=1),  
            nn.Dropout(0.2), 
            nn.ReLU(),
            nn.Conv2d(2048, 4096, 1, stride=1, padding=0),
            nn.Dropout(0.2),  
            nn.ReLU(),
        )
        self.a_decoder = nn.Sequential(
            nn.Conv2d(4096, 2048, 1, stride=1, padding=0),  
            nn.ReLU(),
            nn.ConvTranspose2d(2048, 1024, 4, stride=2, padding=1), 
            nn.ReLU(),
            nn.ConvTranspose2d(1024, 512, 4, stride=2, padding=1), 
            nn.ReLU(),
            nn.ConvTranspose2d(512, 3, 4, stride=2, padding=1),
            nn.Tanh()
        )
        self.b_decoder = nn.Sequential(
            nn.Conv2d(4096, 2048, 1, stride=1, padding=0),  
            nn.ReLU(),
            nn.ConvTranspose2d(2048, 1024, 4, stride=2, padding=1), 
            nn.ReLU(),
            nn.ConvTranspose2d(1024, 512, 4, stride=2, padding=1), 
            nn.ReLU(),
            nn.ConvTranspose2d(512, 3, 4, stride=2, padding=1),
            nn.Tanh()
        )

    def forward(self, x, Type=None):
        x = self.encoder(x)
        if Type == "A":
          x = self.a_decoder(x)
        elif Type == "B":
          x = self.b_decoder(x)
        return x

# %%
num_epochs = 2500

# Warm up
warm_up_ratio = 0.1
step = len(A_train_loader)
total_step = num_epochs * step

model = conv_autoencoder()
model.cuda()

A_optimizer = torch.optim.RAdam([
                {'params': model.encoder.parameters()},
                {'params': model.a_decoder.parameters()}
                ], lr=1e-4, weight_decay=0)
B_optimizer = torch.optim.RAdam([
                {'params': model.encoder.parameters()},
                {'params': model.b_decoder.parameters()}
                ], lr=1e-4, weight_decay=0)

A_scheduler = get_linear_schedule_with_warmup(A_optimizer, num_warmup_steps = warm_up_ratio * total_step, num_training_steps = total_step)
B_scheduler = get_linear_schedule_with_warmup(B_optimizer, num_warmup_steps = warm_up_ratio * total_step, num_training_steps = total_step)

# %%
seed = 0
best_loss = np.inf
model.train()

for epoch in range(num_epochs):

    tot_loss = list()
    # Train A face
    for data, _ in A_train_loader:
        # ===================loading=====================
        torch.random.manual_seed(seed)
        img = addition_tfm(data).cuda()
        torch.random.manual_seed(seed)
        crop_img = addition_tfm(crop_face(data[0])).cuda()
        # ================A face forward===============
        output = model(torch.unsqueeze(crop_img.float(), 0), "A")
        loss = F.mse_loss(output, img)
        tot_loss.append(loss.item())
        # ===================backward====================
        A_optimizer.zero_grad()
        loss.backward()
        A_optimizer.step()
        A_scheduler.step()
        seed += 1

    # Train B face
    for data, _ in B_train_loader:
        # ===================loading=====================
        torch.random.manual_seed(seed)
        img = addition_tfm(data).cuda()
        torch.random.manual_seed(seed)
        crop_img = addition_tfm(crop_face(data[0])).cuda()
        # ================B face forward===============
        output = model(torch.unsqueeze(crop_img.float(), 0), "B")
        loss = F.mse_loss(output, img)
        tot_loss.append(loss.item())
        # ===================backward====================
        B_optimizer.zero_grad()
        loss.backward()
        B_optimizer.step()
        B_scheduler.step()
        seed += 1
        
    # ===================save_best====================
    mean_loss = np.mean(tot_loss)
    if mean_loss < best_loss:
        best_loss = mean_loss
        torch.save(model, 'best_model_cnn.pt')
    # ===================log========================
    print(f"Epoch {epoch + 1:.0f}/{num_epochs:.0f} | loss = {mean_loss:.7f}")
# Out:
# Epoch 1/2500 | loss = 0.4547490
# Epoch 2/2500 | loss = 0.2872172
# Epoch 3/2500 | loss = 0.1383852
# Epoch 4/2500 | loss = 0.1059546
# Epoch 5/2500 | loss = 0.0954294
# Epoch 6/2500 | loss = 0.0877811
# Epoch 7/2500 | loss = 0.0809786
# Epoch 8/2500 | loss = 0.0745211
# Epoch 9/2500 | loss = 0.0679525
# Epoch 10/2500 | loss = 0.0601348
# Epoch 11/2500 | loss = 0.0547718
# Epoch 12/2500 | loss = 0.0506654
# Epoch 13/2500 | loss = 0.0476283
# Epoch 14/2500 | loss = 0.0448601
# Epoch 15/2500 | loss = 0.0421952
# Epoch 16/2500 | loss = 0.0400175
# Epoch 17/2500 | loss = 0.0371264
# Epoch 18/2500 | loss = 0.0342330
# Epoch 19/2500 | loss = 0.0312573
# Epoch 20/2500 | loss = 0.0291154
# Epoch 21/2500 | loss = 0.0274727
# Epoch 22/2500 | loss = 0.0260149
# Epoch 23/2500 | loss = 0.0255120
# Epoch 24/2500 | loss = 0.0243721
# Epoch 25/2500 | loss = 0.0239398
# Epoch 26/2500 | loss = 0.0230200
# Epoch 27/2500 | loss = 0.0222973
# Epoch 28/2500 | loss = 0.0221865
# Epoch 29/2500 | loss = 0.0216441
# Epoch 30/2500 | loss = 0.0208864
# Epoch 31/2500 | loss = 0.0207232
# Epoch 32/2500 | loss = 0.0205311
# Epoch 33/2500 | loss = 0.0201107
# Epoch 34/2500 | loss = 0.0195949
# Epoch 35/2500 | loss = 0.0198325
# Epoch 36/2500 | loss = 0.0189100
# Epoch 37/2500 | loss = 0.0189827
# Epoch 38/2500 | loss = 0.0185005
# Epoch 39/2500 | loss = 0.0178568
# Epoch 40/2500 | loss = 0.0177611
# Epoch 41/2500 | loss = 0.0178849
# Epoch 42/2500 | loss = 0.0170817
# Epoch 43/2500 | loss = 0.0170863
# Epoch 44/2500 | loss = 0.0169979
# Epoch 45/2500 | loss = 0.0172592
# Epoch 46/2500 | loss = 0.0167271
# Epoch 47/2500 | loss = 0.0164424
# Epoch 48/2500 | loss = 0.0161940
# Epoch 49/2500 | loss = 0.0158546
# Epoch 50/2500 | loss = 0.0158464
# Epoch 51/2500 | loss = 0.0160395
# Epoch 52/2500 | loss = 0.0153077
# Epoch 53/2500 | loss = 0.0155529
# Epoch 54/2500 | loss = 0.0151203
# Epoch 55/2500 | loss = 0.0150888
# Epoch 56/2500 | loss = 0.0150059
# Epoch 57/2500 | loss = 0.0147941
# Epoch 58/2500 | loss = 0.0151031
# Epoch 59/2500 | loss = 0.0143839
# Epoch 60/2500 | loss = 0.0146212
# Epoch 61/2500 | loss = 0.0140441
# Epoch 62/2500 | loss = 0.0139996
# Epoch 63/2500 | loss = 0.0135228
# Epoch 64/2500 | loss = 0.0136623
# Epoch 65/2500 | loss = 0.0136636
# Epoch 66/2500 | loss = 0.0135750
# Epoch 67/2500 | loss = 0.0138630
# Epoch 68/2500 | loss = 0.0136768
# Epoch 69/2500 | loss = 0.0131057
# Epoch 70/2500 | loss = 0.0130324
# Epoch 71/2500 | loss = 0.0131919
# Epoch 72/2500 | loss = 0.0135109
# Epoch 73/2500 | loss = 0.0130785
# Epoch 74/2500 | loss = 0.0129802
# Epoch 75/2500 | loss = 0.0132796
# Epoch 76/2500 | loss = 0.0125104
# Epoch 77/2500 | loss = 0.0122213
# Epoch 78/2500 | loss = 0.0125886
# Epoch 79/2500 | loss = 0.0122063
# Epoch 80/2500 | loss = 0.0120872
# Epoch 81/2500 | loss = 0.0120490
# Epoch 82/2500 | loss = 0.0121802
# Epoch 83/2500 | loss = 0.0128272
# Epoch 84/2500 | loss = 0.0124724
# Epoch 85/2500 | loss = 0.0116872
# Epoch 86/2500 | loss = 0.0115430
# Epoch 87/2500 | loss = 0.0114872
# Epoch 88/2500 | loss = 0.0119859
# Epoch 89/2500 | loss = 0.0119231
# Epoch 90/2500 | loss = 0.0116900
# Epoch 91/2500 | loss = 0.0112290
# Epoch 92/2500 | loss = 0.0111742
# Epoch 93/2500 | loss = 0.0110190
# Epoch 94/2500 | loss = 0.0107525
# Epoch 95/2500 | loss = 0.0112675
# Epoch 96/2500 | loss = 0.0115165
# Epoch 97/2500 | loss = 0.0113337
# Epoch 98/2500 | loss = 0.0109499
# Epoch 99/2500 | loss = 0.0107442
# Epoch 100/2500 | loss = 0.0106108
# Epoch 101/2500 | loss = 0.0106822
# Epoch 102/2500 | loss = 0.0110397
# Epoch 103/2500 | loss = 0.0110508
# Epoch 104/2500 | loss = 0.0103631
# Epoch 105/2500 | loss = 0.0106753
# Epoch 106/2500 | loss = 0.0109388
# Epoch 107/2500 | loss = 0.0101891
# Epoch 108/2500 | loss = 0.0105046
# Epoch 109/2500 | loss = 0.0106018
# Epoch 110/2500 | loss = 0.0107480
# Epoch 111/2500 | loss = 0.0102987
# Epoch 112/2500 | loss = 0.0100446
# Epoch 113/2500 | loss = 0.0105683
# Epoch 114/2500 | loss = 0.0102123
# Epoch 115/2500 | loss = 0.0099816
# Epoch 116/2500 | loss = 0.0095825
# Epoch 117/2500 | loss = 0.0097243
# Epoch 118/2500 | loss = 0.0096693
# Epoch 119/2500 | loss = 0.0096170
# Epoch 120/2500 | loss = 0.0099047
# Epoch 121/2500 | loss = 0.0095063
# Epoch 122/2500 | loss = 0.0093858
# Epoch 123/2500 | loss = 0.0096940
# Epoch 124/2500 | loss = 0.0098962
# Epoch 125/2500 | loss = 0.0097827
# Epoch 126/2500 | loss = 0.0092516
# Epoch 127/2500 | loss = 0.0091097
# Epoch 128/2500 | loss = 0.0088029
# Epoch 129/2500 | loss = 0.0105249
# Epoch 130/2500 | loss = 0.0097475
# Epoch 131/2500 | loss = 0.0091321
# Epoch 132/2500 | loss = 0.0093052
# Epoch 133/2500 | loss = 0.0090655
# Epoch 134/2500 | loss = 0.0089145
# Epoch 135/2500 | loss = 0.0090305
# Epoch 136/2500 | loss = 0.0096593
# Epoch 137/2500 | loss = 0.0094207
# Epoch 138/2500 | loss = 0.0088034
# Epoch 139/2500 | loss = 0.0086975
# Epoch 140/2500 | loss = 0.0085358
# Epoch 141/2500 | loss = 0.0086746
# Epoch 142/2500 | loss = 0.0087187
# Epoch 143/2500 | loss = 0.0082400
# Epoch 144/2500 | loss = 0.0088262
# Epoch 145/2500 | loss = 0.0090055
# Epoch 146/2500 | loss = 0.0085183
# Epoch 147/2500 | loss = 0.0084102
# Epoch 148/2500 | loss = 0.0088516
# Epoch 149/2500 | loss = 0.0090548
# Epoch 150/2500 | loss = 0.0082969
# Epoch 151/2500 | loss = 0.0082300
# Epoch 152/2500 | loss = 0.0083745
# Epoch 153/2500 | loss = 0.0082344
# Epoch 154/2500 | loss = 0.0081833
# Epoch 155/2500 | loss = 0.0081736
# Epoch 156/2500 | loss = 0.0077507
# Epoch 157/2500 | loss = 0.0086391
# Epoch 158/2500 | loss = 0.0084334
# Epoch 159/2500 | loss = 0.0082258
# Epoch 160/2500 | loss = 0.0082337
# Epoch 161/2500 | loss = 0.0078521
# Epoch 162/2500 | loss = 0.0078100
# Epoch 163/2500 | loss = 0.0075617
# Epoch 164/2500 | loss = 0.0079867
# Epoch 165/2500 | loss = 0.0079798
# Epoch 166/2500 | loss = 0.0082565
# Epoch 167/2500 | loss = 0.0078039
# Epoch 168/2500 | loss = 0.0075546
# Epoch 169/2500 | loss = 0.0079430
# Epoch 170/2500 | loss = 0.0076806
# Epoch 171/2500 | loss = 0.0076694
# Epoch 172/2500 | loss = 0.0075821
# Epoch 173/2500 | loss = 0.0077977
# Epoch 174/2500 | loss = 0.0077387
# Epoch 175/2500 | loss = 0.0077552
# Epoch 176/2500 | loss = 0.0086688
# Epoch 177/2500 | loss = 0.0079639
# Epoch 178/2500 | loss = 0.0075783
# Epoch 179/2500 | loss = 0.0076043
# Epoch 180/2500 | loss = 0.0083569
# Epoch 181/2500 | loss = 0.0076970
# Epoch 182/2500 | loss = 0.0073079
# Epoch 183/2500 | loss = 0.0075398
# Epoch 184/2500 | loss = 0.0073588
# Epoch 185/2500 | loss = 0.0076482
# Epoch 186/2500 | loss = 0.0075228
# Epoch 187/2500 | loss = 0.0072547
# Epoch 188/2500 | loss = 0.0074089
# Epoch 189/2500 | loss = 0.0072288
# Epoch 190/2500 | loss = 0.0069531
# Epoch 191/2500 | loss = 0.0071754
# Epoch 192/2500 | loss = 0.0070978
# Epoch 193/2500 | loss = 0.0071209
# Epoch 194/2500 | loss = 0.0072849
# Epoch 195/2500 | loss = 0.0070430
# Epoch 196/2500 | loss = 0.0068034
# Epoch 197/2500 | loss = 0.0070245
# Epoch 198/2500 | loss = 0.0073440
# Epoch 199/2500 | loss = 0.0072206
# Epoch 200/2500 | loss = 0.0070542
# Epoch 201/2500 | loss = 0.0071592
# Epoch 202/2500 | loss = 0.0070529
# Epoch 203/2500 | loss = 0.0073959
# Epoch 204/2500 | loss = 0.0071481
# Epoch 205/2500 | loss = 0.0073123
# Epoch 206/2500 | loss = 0.0071839
# Epoch 207/2500 | loss = 0.0070701
# Epoch 208/2500 | loss = 0.0069901
# Epoch 209/2500 | loss = 0.0069333
# Epoch 210/2500 | loss = 0.0067149
# Epoch 211/2500 | loss = 0.0068700
# Epoch 212/2500 | loss = 0.0070987
# Epoch 213/2500 | loss = 0.0073761
# Epoch 214/2500 | loss = 0.0071763
# Epoch 215/2500 | loss = 0.0071623
# Epoch 216/2500 | loss = 0.0068169
# Epoch 217/2500 | loss = 0.0067557
# Epoch 218/2500 | loss = 0.0065605
# Epoch 219/2500 | loss = 0.0069888
# Epoch 220/2500 | loss = 0.0072523
# Epoch 221/2500 | loss = 0.0068655
# Epoch 222/2500 | loss = 0.0067400
# Epoch 223/2500 | loss = 0.0066774
# Epoch 224/2500 | loss = 0.0068465
# Epoch 225/2500 | loss = 0.0067829
# Epoch 226/2500 | loss = 0.0067902
# Epoch 227/2500 | loss = 0.0066846
# Epoch 228/2500 | loss = 0.0068386
# Epoch 229/2500 | loss = 0.0068929
# Epoch 230/2500 | loss = 0.0067383
# Epoch 231/2500 | loss = 0.0065914
# Epoch 232/2500 | loss = 0.0063783
# Epoch 233/2500 | loss = 0.0068311
# Epoch 234/2500 | loss = 0.0064243
# Epoch 235/2500 | loss = 0.0070135
# Epoch 236/2500 | loss = 0.0066546
# Epoch 237/2500 | loss = 0.0064350
# Epoch 238/2500 | loss = 0.0064466
# Epoch 239/2500 | loss = 0.0066543
# Epoch 240/2500 | loss = 0.0065620
# Epoch 241/2500 | loss = 0.0066123
# Epoch 242/2500 | loss = 0.0065130
# Epoch 243/2500 | loss = 0.0064190
# Epoch 244/2500 | loss = 0.0064056
# Epoch 245/2500 | loss = 0.0068088
# Epoch 246/2500 | loss = 0.0064411
# Epoch 247/2500 | loss = 0.0067322
# Epoch 248/2500 | loss = 0.0064751
# Epoch 249/2500 | loss = 0.0064238
# Epoch 250/2500 | loss = 0.0063385
# Epoch 251/2500 | loss = 0.0062622
# Epoch 252/2500 | loss = 0.0064688
# Epoch 253/2500 | loss = 0.0064720
# Epoch 254/2500 | loss = 0.0064765
# Epoch 255/2500 | loss = 0.0062750
# Epoch 256/2500 | loss = 0.0067153
# Epoch 257/2500 | loss = 0.0064097
# Epoch 258/2500 | loss = 0.0062689
# Epoch 259/2500 | loss = 0.0063734
# Epoch 260/2500 | loss = 0.0062440
# Epoch 261/2500 | loss = 0.0059281
# Epoch 262/2500 | loss = 0.0059646
# Epoch 263/2500 | loss = 0.0060948
# Epoch 264/2500 | loss = 0.0060562
# Epoch 265/2500 | loss = 0.0060452
# Epoch 266/2500 | loss = 0.0058990
# Epoch 267/2500 | loss = 0.0058624
# Epoch 268/2500 | loss = 0.0057287
# Epoch 269/2500 | loss = 0.0059743
# Epoch 270/2500 | loss = 0.0061998
# Epoch 271/2500 | loss = 0.0060721
# Epoch 272/2500 | loss = 0.0060124
# Epoch 273/2500 | loss = 0.0057885
# Epoch 274/2500 | loss = 0.0059028
# Epoch 275/2500 | loss = 0.0061008
# Epoch 276/2500 | loss = 0.0059097
# Epoch 277/2500 | loss = 0.0058321
# Epoch 278/2500 | loss = 0.0057832
# Epoch 279/2500 | loss = 0.0058011
# Epoch 280/2500 | loss = 0.0054932
# Epoch 281/2500 | loss = 0.0054117
# Epoch 282/2500 | loss = 0.0054521
# Epoch 283/2500 | loss = 0.0056761
# Epoch 284/2500 | loss = 0.0056266
# Epoch 285/2500 | loss = 0.0058865
# Epoch 286/2500 | loss = 0.0055696
# Epoch 287/2500 | loss = 0.0056315
# Epoch 288/2500 | loss = 0.0057823
# Epoch 289/2500 | loss = 0.0059278
# Epoch 290/2500 | loss = 0.0055730
# Epoch 291/2500 | loss = 0.0056635
# Epoch 292/2500 | loss = 0.0054437
# Epoch 293/2500 | loss = 0.0054387
# Epoch 294/2500 | loss = 0.0057953
# Epoch 295/2500 | loss = 0.0057277
# Epoch 296/2500 | loss = 0.0055481
# Epoch 297/2500 | loss = 0.0054383
# Epoch 298/2500 | loss = 0.0054684
# Epoch 299/2500 | loss = 0.0054082
# Epoch 300/2500 | loss = 0.0055157
# Epoch 301/2500 | loss = 0.0053712
# Epoch 302/2500 | loss = 0.0053845
# Epoch 303/2500 | loss = 0.0050641
# Epoch 304/2500 | loss = 0.0052482
# Epoch 305/2500 | loss = 0.0054176
# Epoch 306/2500 | loss = 0.0054037
# Epoch 307/2500 | loss = 0.0053919
# Epoch 308/2500 | loss = 0.0055870
# Epoch 309/2500 | loss = 0.0051206
# Epoch 310/2500 | loss = 0.0052710
# Epoch 311/2500 | loss = 0.0052929
# Epoch 312/2500 | loss = 0.0051736
# Epoch 313/2500 | loss = 0.0052289
# Epoch 314/2500 | loss = 0.0052188
# Epoch 315/2500 | loss = 0.0051513
# Epoch 316/2500 | loss = 0.0052077
# Epoch 317/2500 | loss = 0.0050833
# Epoch 318/2500 | loss = 0.0051365
# Epoch 319/2500 | loss = 0.0051446
# Epoch 320/2500 | loss = 0.0052649
# Epoch 321/2500 | loss = 0.0050955
# Epoch 322/2500 | loss = 0.0048576
# Epoch 323/2500 | loss = 0.0049272
# Epoch 324/2500 | loss = 0.0049906
# Epoch 325/2500 | loss = 0.0051941
# Epoch 326/2500 | loss = 0.0049689
# Epoch 327/2500 | loss = 0.0049979
# Epoch 328/2500 | loss = 0.0047413
# Epoch 329/2500 | loss = 0.0050072
# Epoch 330/2500 | loss = 0.0048946
# Epoch 331/2500 | loss = 0.0048799
# Epoch 332/2500 | loss = 0.0049797
# Epoch 333/2500 | loss = 0.0050177
# Epoch 334/2500 | loss = 0.0049671
# Epoch 335/2500 | loss = 0.0050388
# Epoch 336/2500 | loss = 0.0049892
# Epoch 337/2500 | loss = 0.0049585
# Epoch 338/2500 | loss = 0.0053497
# Epoch 339/2500 | loss = 0.0050629
# Epoch 340/2500 | loss = 0.0050696
# Epoch 341/2500 | loss = 0.0047545
# Epoch 342/2500 | loss = 0.0049279
# Epoch 343/2500 | loss = 0.0047921
# Epoch 344/2500 | loss = 0.0048236
# Epoch 345/2500 | loss = 0.0048667
# Epoch 346/2500 | loss = 0.0046617
# Epoch 347/2500 | loss = 0.0047169
# Epoch 348/2500 | loss = 0.0047384
# Epoch 349/2500 | loss = 0.0048233
# Epoch 350/2500 | loss = 0.0048431
# Epoch 351/2500 | loss = 0.0050338
# Epoch 352/2500 | loss = 0.0048647
# Epoch 353/2500 | loss = 0.0047846
# Epoch 354/2500 | loss = 0.0046280
# Epoch 355/2500 | loss = 0.0045926
# Epoch 356/2500 | loss = 0.0046582
# Epoch 357/2500 | loss = 0.0046379
# Epoch 358/2500 | loss = 0.0047272
# Epoch 359/2500 | loss = 0.0047479
# Epoch 360/2500 | loss = 0.0046348
# Epoch 361/2500 | loss = 0.0045424
# Epoch 362/2500 | loss = 0.0045214
# Epoch 363/2500 | loss = 0.0047926
# Epoch 364/2500 | loss = 0.0045865
# Epoch 365/2500 | loss = 0.0045569
# Epoch 366/2500 | loss = 0.0046124
# Epoch 367/2500 | loss = 0.0046021
# Epoch 368/2500 | loss = 0.0045137
# Epoch 369/2500 | loss = 0.0046934
# Epoch 370/2500 | loss = 0.0045547
# Epoch 371/2500 | loss = 0.0045371
# Epoch 372/2500 | loss = 0.0046187
# Epoch 373/2500 | loss = 0.0044128
# Epoch 374/2500 | loss = 0.0045503
# Epoch 375/2500 | loss = 0.0045394
# Epoch 376/2500 | loss = 0.0044156
# Epoch 377/2500 | loss = 0.0045197
# Epoch 378/2500 | loss = 0.0045432
# Epoch 379/2500 | loss = 0.0044738
# Epoch 380/2500 | loss = 0.0045110
# Epoch 381/2500 | loss = 0.0045462
# Epoch 382/2500 | loss = 0.0044910
# Epoch 383/2500 | loss = 0.0045914
# Epoch 384/2500 | loss = 0.0043768
# Epoch 385/2500 | loss = 0.0043795
# Epoch 386/2500 | loss = 0.0044872
# Epoch 387/2500 | loss = 0.0044153
# Epoch 388/2500 | loss = 0.0044510
# Epoch 389/2500 | loss = 0.0044104
# Epoch 390/2500 | loss = 0.0043182
# Epoch 391/2500 | loss = 0.0043937
# Epoch 392/2500 | loss = 0.0043983
# Epoch 393/2500 | loss = 0.0041946
# Epoch 394/2500 | loss = 0.0042874
# Epoch 395/2500 | loss = 0.0043341
# Epoch 396/2500 | loss = 0.0042677
# Epoch 397/2500 | loss = 0.0042444
# Epoch 398/2500 | loss = 0.0042997
# Epoch 399/2500 | loss = 0.0043468
# Epoch 400/2500 | loss = 0.0042806
# Epoch 401/2500 | loss = 0.0042449
# Epoch 402/2500 | loss = 0.0042160
# Epoch 403/2500 | loss = 0.0042817
# Epoch 404/2500 | loss = 0.0042234
# Epoch 405/2500 | loss = 0.0042551
# Epoch 406/2500 | loss = 0.0043266
# Epoch 407/2500 | loss = 0.0043254
# Epoch 408/2500 | loss = 0.0042209
# Epoch 409/2500 | loss = 0.0041313
# Epoch 410/2500 | loss = 0.0043609
# Epoch 411/2500 | loss = 0.0042665
# Epoch 412/2500 | loss = 0.0041243
# Epoch 413/2500 | loss = 0.0041798
# Epoch 414/2500 | loss = 0.0042942
# Epoch 415/2500 | loss = 0.0040738
# Epoch 416/2500 | loss = 0.0041005
# Epoch 417/2500 | loss = 0.0040941
# Epoch 418/2500 | loss = 0.0040913
# Epoch 419/2500 | loss = 0.0041562
# Epoch 420/2500 | loss = 0.0041699
# Epoch 421/2500 | loss = 0.0042602
# Epoch 422/2500 | loss = 0.0040194
# Epoch 423/2500 | loss = 0.0041178
# Epoch 424/2500 | loss = 0.0042140
# Epoch 425/2500 | loss = 0.0042134
# Epoch 426/2500 | loss = 0.0040861
# Epoch 427/2500 | loss = 0.0040227
# Epoch 428/2500 | loss = 0.0040715
# Epoch 429/2500 | loss = 0.0041865
# Epoch 430/2500 | loss = 0.0041877
# Epoch 431/2500 | loss = 0.0040991
# Epoch 432/2500 | loss = 0.0040204
# Epoch 433/2500 | loss = 0.0040217
# Epoch 434/2500 | loss = 0.0041148
# Epoch 435/2500 | loss = 0.0040175
# Epoch 436/2500 | loss = 0.0038971
# Epoch 437/2500 | loss = 0.0040074
# Epoch 438/2500 | loss = 0.0040744
# Epoch 439/2500 | loss = 0.0038554
# Epoch 440/2500 | loss = 0.0040095
# Epoch 441/2500 | loss = 0.0040080
# Epoch 442/2500 | loss = 0.0042800
# Epoch 443/2500 | loss = 0.0039883
# Epoch 444/2500 | loss = 0.0040124
# Epoch 445/2500 | loss = 0.0038695
# Epoch 446/2500 | loss = 0.0040669
# Epoch 447/2500 | loss = 0.0040617
# Epoch 448/2500 | loss = 0.0040262
# Epoch 449/2500 | loss = 0.0038986
# Epoch 450/2500 | loss = 0.0039845
# Epoch 451/2500 | loss = 0.0038910
# Epoch 452/2500 | loss = 0.0038448
# Epoch 453/2500 | loss = 0.0040106
# Epoch 454/2500 | loss = 0.0039569
# Epoch 455/2500 | loss = 0.0039539
# Epoch 456/2500 | loss = 0.0039094
# Epoch 457/2500 | loss = 0.0039397
# Epoch 458/2500 | loss = 0.0040262
# Epoch 459/2500 | loss = 0.0038959
# Epoch 460/2500 | loss = 0.0037924
# Epoch 461/2500 | loss = 0.0038977
# Epoch 462/2500 | loss = 0.0038799
# Epoch 463/2500 | loss = 0.0038755
# Epoch 464/2500 | loss = 0.0037342
# Epoch 465/2500 | loss = 0.0039606
# Epoch 466/2500 | loss = 0.0038892
# Epoch 467/2500 | loss = 0.0038228
# Epoch 468/2500 | loss = 0.0039966
# Epoch 469/2500 | loss = 0.0038802
# Epoch 470/2500 | loss = 0.0038392
# Epoch 471/2500 | loss = 0.0039405
# Epoch 472/2500 | loss = 0.0038958
# Epoch 473/2500 | loss = 0.0039222
# Epoch 474/2500 | loss = 0.0037657
# Epoch 475/2500 | loss = 0.0038536
# Epoch 476/2500 | loss = 0.0037100
# Epoch 477/2500 | loss = 0.0037622
# Epoch 478/2500 | loss = 0.0037413
# Epoch 479/2500 | loss = 0.0038659
# Epoch 480/2500 | loss = 0.0037554
# Epoch 481/2500 | loss = 0.0036412
# Epoch 482/2500 | loss = 0.0038076
# Epoch 483/2500 | loss = 0.0037755
# Epoch 484/2500 | loss = 0.0038198
# Epoch 485/2500 | loss = 0.0037680
# Epoch 486/2500 | loss = 0.0037123
# Epoch 487/2500 | loss = 0.0035757
# Epoch 488/2500 | loss = 0.0036902
# Epoch 489/2500 | loss = 0.0037626
# Epoch 490/2500 | loss = 0.0038296
# Epoch 491/2500 | loss = 0.0037397
# Epoch 492/2500 | loss = 0.0037500
# Epoch 493/2500 | loss = 0.0038455
# Epoch 494/2500 | loss = 0.0036771
# Epoch 495/2500 | loss = 0.0037338
# Epoch 496/2500 | loss = 0.0036846
# Epoch 497/2500 | loss = 0.0036532
# Epoch 498/2500 | loss = 0.0036502
# Epoch 499/2500 | loss = 0.0037680
# Epoch 500/2500 | loss = 0.0037064
# Epoch 501/2500 | loss = 0.0036615
# Epoch 502/2500 | loss = 0.0036970
# Epoch 503/2500 | loss = 0.0036658
# Epoch 504/2500 | loss = 0.0035617
# Epoch 505/2500 | loss = 0.0037302
# Epoch 506/2500 | loss = 0.0036912
# Epoch 507/2500 | loss = 0.0037251
# Epoch 508/2500 | loss = 0.0035749
# Epoch 509/2500 | loss = 0.0036418
# Epoch 510/2500 | loss = 0.0036680
# Epoch 511/2500 | loss = 0.0035610
# Epoch 512/2500 | loss = 0.0035969
# Epoch 513/2500 | loss = 0.0035380
# Epoch 514/2500 | loss = 0.0035754
# Epoch 515/2500 | loss = 0.0035901
# Epoch 516/2500 | loss = 0.0036387
# Epoch 517/2500 | loss = 0.0034931
# Epoch 518/2500 | loss = 0.0035316
# Epoch 519/2500 | loss = 0.0035632
# Epoch 520/2500 | loss = 0.0034901
# Epoch 521/2500 | loss = 0.0035895
# Epoch 522/2500 | loss = 0.0034642
# Epoch 523/2500 | loss = 0.0035172
# Epoch 524/2500 | loss = 0.0035929
# Epoch 525/2500 | loss = 0.0035909
# Epoch 526/2500 | loss = 0.0034904
# Epoch 527/2500 | loss = 0.0035584
# Epoch 528/2500 | loss = 0.0034666
# Epoch 529/2500 | loss = 0.0037165
# Epoch 530/2500 | loss = 0.0035686
# Epoch 531/2500 | loss = 0.0035180
# Epoch 532/2500 | loss = 0.0036297
# Epoch 533/2500 | loss = 0.0035794
# Epoch 534/2500 | loss = 0.0036488
# Epoch 535/2500 | loss = 0.0036878
# Epoch 536/2500 | loss = 0.0035572
# Epoch 537/2500 | loss = 0.0035294
# Epoch 538/2500 | loss = 0.0034779
# Epoch 539/2500 | loss = 0.0036701
# Epoch 540/2500 | loss = 0.0035767
# Epoch 541/2500 | loss = 0.0035085
# Epoch 542/2500 | loss = 0.0035209
# Epoch 543/2500 | loss = 0.0035182
# Epoch 544/2500 | loss = 0.0035045
# Epoch 545/2500 | loss = 0.0034686
# Epoch 546/2500 | loss = 0.0034777
# Epoch 547/2500 | loss = 0.0034086
# Epoch 548/2500 | loss = 0.0034131
# Epoch 549/2500 | loss = 0.0035210
# Epoch 550/2500 | loss = 0.0034219
# Epoch 551/2500 | loss = 0.0034457
# Epoch 552/2500 | loss = 0.0033791
# Epoch 553/2500 | loss = 0.0034837
# Epoch 554/2500 | loss = 0.0035033
# Epoch 555/2500 | loss = 0.0034400
# Epoch 556/2500 | loss = 0.0033133
# Epoch 557/2500 | loss = 0.0034433
# Epoch 558/2500 | loss = 0.0034452
# Epoch 559/2500 | loss = 0.0033838
# Epoch 560/2500 | loss = 0.0033725
# Epoch 561/2500 | loss = 0.0033753
# Epoch 562/2500 | loss = 0.0032897
# Epoch 563/2500 | loss = 0.0034247
# Epoch 564/2500 | loss = 0.0033935
# Epoch 565/2500 | loss = 0.0034034
# Epoch 566/2500 | loss = 0.0033223
# Epoch 567/2500 | loss = 0.0033377
# Epoch 568/2500 | loss = 0.0033878
# Epoch 569/2500 | loss = 0.0033793
# Epoch 570/2500 | loss = 0.0033780
# Epoch 571/2500 | loss = 0.0033886
# Epoch 572/2500 | loss = 0.0033706
# Epoch 573/2500 | loss = 0.0035069
# Epoch 574/2500 | loss = 0.0033898
# Epoch 575/2500 | loss = 0.0033972
# Epoch 576/2500 | loss = 0.0033480
# Epoch 577/2500 | loss = 0.0032917
# Epoch 578/2500 | loss = 0.0032849
# Epoch 579/2500 | loss = 0.0032919
# Epoch 580/2500 | loss = 0.0033107
# Epoch 581/2500 | loss = 0.0033410
# Epoch 582/2500 | loss = 0.0033622
# Epoch 583/2500 | loss = 0.0034006
# Epoch 584/2500 | loss = 0.0033862
# Epoch 585/2500 | loss = 0.0033529
# Epoch 586/2500 | loss = 0.0033526
# Epoch 587/2500 | loss = 0.0034260
# Epoch 588/2500 | loss = 0.0034087
# Epoch 589/2500 | loss = 0.0032414
# Epoch 590/2500 | loss = 0.0032942
# Epoch 591/2500 | loss = 0.0034037
# Epoch 592/2500 | loss = 0.0033425
# Epoch 593/2500 | loss = 0.0032673
# Epoch 594/2500 | loss = 0.0034139
# Epoch 595/2500 | loss = 0.0033159
# Epoch 596/2500 | loss = 0.0032639
# Epoch 597/2500 | loss = 0.0031778
# Epoch 598/2500 | loss = 0.0032191
# Epoch 599/2500 | loss = 0.0032890
# Epoch 600/2500 | loss = 0.0032585
# Epoch 601/2500 | loss = 0.0031925
# Epoch 602/2500 | loss = 0.0031673
# Epoch 603/2500 | loss = 0.0031685
# Epoch 604/2500 | loss = 0.0032111
# Epoch 605/2500 | loss = 0.0032368
# Epoch 606/2500 | loss = 0.0032579
# Epoch 607/2500 | loss = 0.0032829
# Epoch 608/2500 | loss = 0.0031644
# Epoch 609/2500 | loss = 0.0032869
# Epoch 610/2500 | loss = 0.0032612
# Epoch 611/2500 | loss = 0.0031879
# Epoch 612/2500 | loss = 0.0031831
# Epoch 613/2500 | loss = 0.0031757
# Epoch 614/2500 | loss = 0.0033190
# Epoch 615/2500 | loss = 0.0032633
# Epoch 616/2500 | loss = 0.0033250
# Epoch 617/2500 | loss = 0.0031946
# Epoch 618/2500 | loss = 0.0031981
# Epoch 619/2500 | loss = 0.0031844
# Epoch 620/2500 | loss = 0.0031877
# Epoch 621/2500 | loss = 0.0032130
# Epoch 622/2500 | loss = 0.0031667
# Epoch 623/2500 | loss = 0.0031255
# Epoch 624/2500 | loss = 0.0031287
# Epoch 625/2500 | loss = 0.0031268
# Epoch 626/2500 | loss = 0.0031978
# Epoch 627/2500 | loss = 0.0031909
# Epoch 628/2500 | loss = 0.0032511
# Epoch 629/2500 | loss = 0.0031412
# Epoch 630/2500 | loss = 0.0031567
# Epoch 631/2500 | loss = 0.0032716
# Epoch 632/2500 | loss = 0.0031487
# Epoch 633/2500 | loss = 0.0031843
# Epoch 634/2500 | loss = 0.0031238
# Epoch 635/2500 | loss = 0.0031331
# Epoch 636/2500 | loss = 0.0031562
# Epoch 637/2500 | loss = 0.0031076
# Epoch 638/2500 | loss = 0.0032304
# Epoch 639/2500 | loss = 0.0031822
# Epoch 640/2500 | loss = 0.0032474
# Epoch 641/2500 | loss = 0.0031103
# Epoch 642/2500 | loss = 0.0030857
# Epoch 643/2500 | loss = 0.0030912
# Epoch 644/2500 | loss = 0.0032622
# Epoch 645/2500 | loss = 0.0032637
# Epoch 646/2500 | loss = 0.0032091
# Epoch 647/2500 | loss = 0.0032321
# Epoch 648/2500 | loss = 0.0030984
# Epoch 649/2500 | loss = 0.0030754
# Epoch 650/2500 | loss = 0.0030177
# Epoch 651/2500 | loss = 0.0031105
# Epoch 652/2500 | loss = 0.0030684
# Epoch 653/2500 | loss = 0.0030523
# Epoch 654/2500 | loss = 0.0030942
# Epoch 655/2500 | loss = 0.0030129
# Epoch 656/2500 | loss = 0.0030849
# Epoch 657/2500 | loss = 0.0030642
# Epoch 658/2500 | loss = 0.0030972
# Epoch 659/2500 | loss = 0.0030356
# Epoch 660/2500 | loss = 0.0031001
# Epoch 661/2500 | loss = 0.0030187
# Epoch 662/2500 | loss = 0.0031440
# Epoch 663/2500 | loss = 0.0030928
# Epoch 664/2500 | loss = 0.0030239
# Epoch 665/2500 | loss = 0.0031170
# Epoch 666/2500 | loss = 0.0030282
# Epoch 667/2500 | loss = 0.0030838
# Epoch 668/2500 | loss = 0.0030662
# Epoch 669/2500 | loss = 0.0030362
# Epoch 670/2500 | loss = 0.0029547
# Epoch 671/2500 | loss = 0.0031094
# Epoch 672/2500 | loss = 0.0030413
# Epoch 673/2500 | loss = 0.0030910
# Epoch 674/2500 | loss = 0.0029943
# Epoch 675/2500 | loss = 0.0030969
# Epoch 676/2500 | loss = 0.0030069
# Epoch 677/2500 | loss = 0.0030155
# Epoch 678/2500 | loss = 0.0030377
# Epoch 679/2500 | loss = 0.0030424
# Epoch 680/2500 | loss = 0.0030434
# Epoch 681/2500 | loss = 0.0030591
# Epoch 682/2500 | loss = 0.0030169
# Epoch 683/2500 | loss = 0.0029834
# Epoch 684/2500 | loss = 0.0029224
# Epoch 685/2500 | loss = 0.0030132
# Epoch 686/2500 | loss = 0.0029910
# Epoch 687/2500 | loss = 0.0029811
# Epoch 688/2500 | loss = 0.0029700
# Epoch 689/2500 | loss = 0.0029933
# Epoch 690/2500 | loss = 0.0029787
# Epoch 691/2500 | loss = 0.0030092
# Epoch 692/2500 | loss = 0.0030043
# Epoch 693/2500 | loss = 0.0030757
# Epoch 694/2500 | loss = 0.0029464
# Epoch 695/2500 | loss = 0.0029425
# Epoch 696/2500 | loss = 0.0029120
# Epoch 697/2500 | loss = 0.0030029
# Epoch 698/2500 | loss = 0.0028885
# Epoch 699/2500 | loss = 0.0029262
# Epoch 700/2500 | loss = 0.0029692
# Epoch 701/2500 | loss = 0.0030444
# Epoch 702/2500 | loss = 0.0031223
# Epoch 703/2500 | loss = 0.0029300
# Epoch 704/2500 | loss = 0.0029547
# Epoch 705/2500 | loss = 0.0029612
# Epoch 706/2500 | loss = 0.0029026
# Epoch 707/2500 | loss = 0.0030488
# Epoch 708/2500 | loss = 0.0030453
# Epoch 709/2500 | loss = 0.0029410
# Epoch 710/2500 | loss = 0.0028682
# Epoch 711/2500 | loss = 0.0028795
# Epoch 712/2500 | loss = 0.0029890
# Epoch 713/2500 | loss = 0.0028561
# Epoch 714/2500 | loss = 0.0029051
# Epoch 715/2500 | loss = 0.0029517
# Epoch 716/2500 | loss = 0.0029172
# Epoch 717/2500 | loss = 0.0029534
# Epoch 718/2500 | loss = 0.0028880
# Epoch 719/2500 | loss = 0.0029530
# Epoch 720/2500 | loss = 0.0029629
# Epoch 721/2500 | loss = 0.0029001
# Epoch 722/2500 | loss = 0.0030409
# Epoch 723/2500 | loss = 0.0029863
# Epoch 724/2500 | loss = 0.0028529
# Epoch 725/2500 | loss = 0.0028514
# Epoch 726/2500 | loss = 0.0028591
# Epoch 727/2500 | loss = 0.0028329
# Epoch 728/2500 | loss = 0.0028579
# Epoch 729/2500 | loss = 0.0028401
# Epoch 730/2500 | loss = 0.0028683
# Epoch 731/2500 | loss = 0.0029479
# Epoch 732/2500 | loss = 0.0028261
# Epoch 733/2500 | loss = 0.0028577
# Epoch 734/2500 | loss = 0.0028267
# Epoch 735/2500 | loss = 0.0028252
# Epoch 736/2500 | loss = 0.0028722
# Epoch 737/2500 | loss = 0.0029607
# Epoch 738/2500 | loss = 0.0028485
# Epoch 739/2500 | loss = 0.0028512
# Epoch 740/2500 | loss = 0.0027931
# Epoch 741/2500 | loss = 0.0029078
# Epoch 742/2500 | loss = 0.0028324
# Epoch 743/2500 | loss = 0.0029601
# Epoch 744/2500 | loss = 0.0029336
# Epoch 745/2500 | loss = 0.0028416
# Epoch 746/2500 | loss = 0.0028119
# Epoch 747/2500 | loss = 0.0027881
# Epoch 748/2500 | loss = 0.0028115
# Epoch 749/2500 | loss = 0.0028111
# Epoch 750/2500 | loss = 0.0028369
# Epoch 751/2500 | loss = 0.0027967
# Epoch 752/2500 | loss = 0.0028255
# Epoch 753/2500 | loss = 0.0028154
# Epoch 754/2500 | loss = 0.0027853
# Epoch 755/2500 | loss = 0.0028758
# Epoch 756/2500 | loss = 0.0028579
# Epoch 757/2500 | loss = 0.0028587
# Epoch 758/2500 | loss = 0.0028819
# Epoch 759/2500 | loss = 0.0028347
# Epoch 760/2500 | loss = 0.0028519
# Epoch 761/2500 | loss = 0.0028948
# Epoch 762/2500 | loss = 0.0027796
# Epoch 763/2500 | loss = 0.0028076
# Epoch 764/2500 | loss = 0.0028142
# Epoch 765/2500 | loss = 0.0028335
# Epoch 766/2500 | loss = 0.0028221
# Epoch 767/2500 | loss = 0.0027529
# Epoch 768/2500 | loss = 0.0028350
# Epoch 769/2500 | loss = 0.0027565
# Epoch 770/2500 | loss = 0.0027338
# Epoch 771/2500 | loss = 0.0027672
# Epoch 772/2500 | loss = 0.0028160
# Epoch 773/2500 | loss = 0.0027969
# Epoch 774/2500 | loss = 0.0028231
# Epoch 775/2500 | loss = 0.0027949
# Epoch 776/2500 | loss = 0.0028141
# Epoch 777/2500 | loss = 0.0027569
# Epoch 778/2500 | loss = 0.0028031
# Epoch 779/2500 | loss = 0.0028657
# Epoch 780/2500 | loss = 0.0027400
# Epoch 781/2500 | loss = 0.0027168
# Epoch 782/2500 | loss = 0.0027121
# Epoch 783/2500 | loss = 0.0026980
# Epoch 784/2500 | loss = 0.0027021
# Epoch 785/2500 | loss = 0.0027428
# Epoch 786/2500 | loss = 0.0027692
# Epoch 787/2500 | loss = 0.0027366
# Epoch 788/2500 | loss = 0.0026979
# Epoch 789/2500 | loss = 0.0027318
# Epoch 790/2500 | loss = 0.0026804
# Epoch 791/2500 | loss = 0.0027790
# Epoch 792/2500 | loss = 0.0029057
# Epoch 793/2500 | loss = 0.0028668
# Epoch 794/2500 | loss = 0.0027216
# Epoch 795/2500 | loss = 0.0027197
# Epoch 796/2500 | loss = 0.0027071
# Epoch 797/2500 | loss = 0.0027106
# Epoch 798/2500 | loss = 0.0027312
# Epoch 799/2500 | loss = 0.0027353
# Epoch 800/2500 | loss = 0.0026851
# Epoch 801/2500 | loss = 0.0026694
# Epoch 802/2500 | loss = 0.0027006
# Epoch 803/2500 | loss = 0.0026918
# Epoch 804/2500 | loss = 0.0028085
# Epoch 805/2500 | loss = 0.0027438
# Epoch 806/2500 | loss = 0.0026944
# Epoch 807/2500 | loss = 0.0027171
# Epoch 808/2500 | loss = 0.0027918
# Epoch 809/2500 | loss = 0.0026836
# Epoch 810/2500 | loss = 0.0027667
# Epoch 811/2500 | loss = 0.0027208
# Epoch 812/2500 | loss = 0.0026607
# Epoch 813/2500 | loss = 0.0026617
# Epoch 814/2500 | loss = 0.0027528
# Epoch 815/2500 | loss = 0.0027435
# Epoch 816/2500 | loss = 0.0026551
# Epoch 817/2500 | loss = 0.0026632
# Epoch 818/2500 | loss = 0.0027962
# Epoch 819/2500 | loss = 0.0026406
# Epoch 820/2500 | loss = 0.0026768
# Epoch 821/2500 | loss = 0.0026205
# Epoch 822/2500 | loss = 0.0026773
# Epoch 823/2500 | loss = 0.0026371
# Epoch 824/2500 | loss = 0.0026243
# Epoch 825/2500 | loss = 0.0026903
# Epoch 826/2500 | loss = 0.0026453
# Epoch 827/2500 | loss = 0.0026490
# Epoch 828/2500 | loss = 0.0026337
# Epoch 829/2500 | loss = 0.0026396
# Epoch 830/2500 | loss = 0.0026082
# Epoch 831/2500 | loss = 0.0026406
# Epoch 832/2500 | loss = 0.0026566
# Epoch 833/2500 | loss = 0.0026366
# Epoch 834/2500 | loss = 0.0027540
# Epoch 835/2500 | loss = 0.0026424
# Epoch 836/2500 | loss = 0.0026583
# Epoch 837/2500 | loss = 0.0025994
# Epoch 838/2500 | loss = 0.0026953
# Epoch 839/2500 | loss = 0.0026518
# Epoch 840/2500 | loss = 0.0026146
# Epoch 841/2500 | loss = 0.0027083
# Epoch 842/2500 | loss = 0.0026561
# Epoch 843/2500 | loss = 0.0027032
# Epoch 844/2500 | loss = 0.0025846
# Epoch 845/2500 | loss = 0.0025551
# Epoch 846/2500 | loss = 0.0026245
# Epoch 847/2500 | loss = 0.0026383
# Epoch 848/2500 | loss = 0.0025977
# Epoch 849/2500 | loss = 0.0025826
# Epoch 850/2500 | loss = 0.0026258
# Epoch 851/2500 | loss = 0.0025887
# Epoch 852/2500 | loss = 0.0026494
# Epoch 853/2500 | loss = 0.0025963
# Epoch 854/2500 | loss = 0.0026628
# Epoch 855/2500 | loss = 0.0026280
# Epoch 856/2500 | loss = 0.0026260
# Epoch 857/2500 | loss = 0.0026093
# Epoch 858/2500 | loss = 0.0025658
# Epoch 859/2500 | loss = 0.0025965
# Epoch 860/2500 | loss = 0.0025233
# Epoch 861/2500 | loss = 0.0026190
# Epoch 862/2500 | loss = 0.0025871
# Epoch 863/2500 | loss = 0.0026011
# Epoch 864/2500 | loss = 0.0025522
# Epoch 865/2500 | loss = 0.0025487
# Epoch 866/2500 | loss = 0.0025437
# Epoch 867/2500 | loss = 0.0026299
# Epoch 868/2500 | loss = 0.0025507
# Epoch 869/2500 | loss = 0.0025214
# Epoch 870/2500 | loss = 0.0025721
# Epoch 871/2500 | loss = 0.0025208
# Epoch 872/2500 | loss = 0.0026069
# Epoch 873/2500 | loss = 0.0025937
# Epoch 874/2500 | loss = 0.0025405
# Epoch 875/2500 | loss = 0.0025496
# Epoch 876/2500 | loss = 0.0025634
# Epoch 877/2500 | loss = 0.0025007
# Epoch 878/2500 | loss = 0.0025222
# Epoch 879/2500 | loss = 0.0025897
# Epoch 880/2500 | loss = 0.0025828
# Epoch 881/2500 | loss = 0.0025665
# Epoch 882/2500 | loss = 0.0025299
# Epoch 883/2500 | loss = 0.0026256
# Epoch 884/2500 | loss = 0.0025226
# Epoch 885/2500 | loss = 0.0025971
# Epoch 886/2500 | loss = 0.0025669
# Epoch 887/2500 | loss = 0.0026171
# Epoch 888/2500 | loss = 0.0025666
# Epoch 889/2500 | loss = 0.0025697
# Epoch 890/2500 | loss = 0.0026351
# Epoch 891/2500 | loss = 0.0025124
# Epoch 892/2500 | loss = 0.0025724
# Epoch 893/2500 | loss = 0.0026252
# Epoch 894/2500 | loss = 0.0026280
# Epoch 895/2500 | loss = 0.0026107
# Epoch 896/2500 | loss = 0.0024979
# Epoch 897/2500 | loss = 0.0024646
# Epoch 898/2500 | loss = 0.0026441
# Epoch 899/2500 | loss = 0.0025170
# Epoch 900/2500 | loss = 0.0025382
# Epoch 901/2500 | loss = 0.0024854
# Epoch 902/2500 | loss = 0.0025147
# Epoch 903/2500 | loss = 0.0024828
# Epoch 904/2500 | loss = 0.0025845
# Epoch 905/2500 | loss = 0.0025720
# Epoch 906/2500 | loss = 0.0025502
# Epoch 907/2500 | loss = 0.0025337
# Epoch 908/2500 | loss = 0.0025326
# Epoch 909/2500 | loss = 0.0025195
# Epoch 910/2500 | loss = 0.0025304
# Epoch 911/2500 | loss = 0.0025278
# Epoch 912/2500 | loss = 0.0025247
# Epoch 913/2500 | loss = 0.0024686
# Epoch 914/2500 | loss = 0.0024657
# Epoch 915/2500 | loss = 0.0025423
# Epoch 916/2500 | loss = 0.0025353
# Epoch 917/2500 | loss = 0.0024680
# Epoch 918/2500 | loss = 0.0024899
# Epoch 919/2500 | loss = 0.0024745
# Epoch 920/2500 | loss = 0.0024482
# Epoch 921/2500 | loss = 0.0024797
# Epoch 922/2500 | loss = 0.0024904
# Epoch 923/2500 | loss = 0.0025034
# Epoch 924/2500 | loss = 0.0026819
# Epoch 925/2500 | loss = 0.0025421
# Epoch 926/2500 | loss = 0.0024879
# Epoch 927/2500 | loss = 0.0025279
# Epoch 928/2500 | loss = 0.0025007
# Epoch 929/2500 | loss = 0.0025369
# Epoch 930/2500 | loss = 0.0024719
# Epoch 931/2500 | loss = 0.0024193
# Epoch 932/2500 | loss = 0.0024564
# Epoch 933/2500 | loss = 0.0024568
# Epoch 934/2500 | loss = 0.0025333
# Epoch 935/2500 | loss = 0.0024961
# Epoch 936/2500 | loss = 0.0024664
# Epoch 937/2500 | loss = 0.0025389
# Epoch 938/2500 | loss = 0.0024841
# Epoch 939/2500 | loss = 0.0024760
# Epoch 940/2500 | loss = 0.0024496
# Epoch 941/2500 | loss = 0.0024689
# Epoch 942/2500 | loss = 0.0024076
# Epoch 943/2500 | loss = 0.0024511
# Epoch 944/2500 | loss = 0.0024031
# Epoch 945/2500 | loss = 0.0024312
# Epoch 946/2500 | loss = 0.0024165
# Epoch 947/2500 | loss = 0.0024777
# Epoch 948/2500 | loss = 0.0024858
# Epoch 949/2500 | loss = 0.0024157
# Epoch 950/2500 | loss = 0.0024230
# Epoch 951/2500 | loss = 0.0024192
# Epoch 952/2500 | loss = 0.0024433
# Epoch 953/2500 | loss = 0.0024968
# Epoch 954/2500 | loss = 0.0024620
# Epoch 955/2500 | loss = 0.0024426
# Epoch 956/2500 | loss = 0.0024073
# Epoch 957/2500 | loss = 0.0024417
# Epoch 958/2500 | loss = 0.0024468
# Epoch 959/2500 | loss = 0.0024197
# Epoch 960/2500 | loss = 0.0024317
# Epoch 961/2500 | loss = 0.0024424
# Epoch 962/2500 | loss = 0.0024983
# Epoch 963/2500 | loss = 0.0024154
# Epoch 964/2500 | loss = 0.0023480
# Epoch 965/2500 | loss = 0.0024354
# Epoch 966/2500 | loss = 0.0024696
# Epoch 967/2500 | loss = 0.0024217
# Epoch 968/2500 | loss = 0.0024831
# Epoch 969/2500 | loss = 0.0023767
# Epoch 970/2500 | loss = 0.0024353
# Epoch 971/2500 | loss = 0.0023916
# Epoch 972/2500 | loss = 0.0023688
# Epoch 973/2500 | loss = 0.0024451
# Epoch 974/2500 | loss = 0.0023394
# Epoch 975/2500 | loss = 0.0024073
# Epoch 976/2500 | loss = 0.0023840
# Epoch 977/2500 | loss = 0.0023382
# Epoch 978/2500 | loss = 0.0023767
# Epoch 979/2500 | loss = 0.0023474
# Epoch 980/2500 | loss = 0.0023709
# Epoch 981/2500 | loss = 0.0024128
# Epoch 982/2500 | loss = 0.0023736
# Epoch 983/2500 | loss = 0.0023725
# Epoch 984/2500 | loss = 0.0023876
# Epoch 985/2500 | loss = 0.0023363
# Epoch 986/2500 | loss = 0.0023526
# Epoch 987/2500 | loss = 0.0023836
# Epoch 988/2500 | loss = 0.0023810
# Epoch 989/2500 | loss = 0.0023685
# Epoch 990/2500 | loss = 0.0024042
# Epoch 991/2500 | loss = 0.0024333
# Epoch 992/2500 | loss = 0.0024047
# Epoch 993/2500 | loss = 0.0024350
# Epoch 994/2500 | loss = 0.0023567
# Epoch 995/2500 | loss = 0.0023630
# Epoch 996/2500 | loss = 0.0023262
# Epoch 997/2500 | loss = 0.0023402
# Epoch 998/2500 | loss = 0.0023845
# Epoch 999/2500 | loss = 0.0024311
# Epoch 1000/2500 | loss = 0.0024317
# Epoch 1001/2500 | loss = 0.0024079
# Epoch 1002/2500 | loss = 0.0023759
# Epoch 1003/2500 | loss = 0.0023502
# Epoch 1004/2500 | loss = 0.0024313
# Epoch 1005/2500 | loss = 0.0026165
# Epoch 1006/2500 | loss = 0.0024414
# Epoch 1007/2500 | loss = 0.0023804
# Epoch 1008/2500 | loss = 0.0023368
# Epoch 1009/2500 | loss = 0.0023754
# Epoch 1010/2500 | loss = 0.0023917
# Epoch 1011/2500 | loss = 0.0023240
# Epoch 1012/2500 | loss = 0.0023019
# Epoch 1013/2500 | loss = 0.0023581
# Epoch 1014/2500 | loss = 0.0023145
# Epoch 1015/2500 | loss = 0.0023068
# Epoch 1016/2500 | loss = 0.0023409
# Epoch 1017/2500 | loss = 0.0022847
# Epoch 1018/2500 | loss = 0.0023421
# Epoch 1019/2500 | loss = 0.0022780
# Epoch 1020/2500 | loss = 0.0023092
# Epoch 1021/2500 | loss = 0.0023838
# Epoch 1022/2500 | loss = 0.0024044
# Epoch 1023/2500 | loss = 0.0023855
# Epoch 1024/2500 | loss = 0.0023147
# Epoch 1025/2500 | loss = 0.0023050
# Epoch 1026/2500 | loss = 0.0023216
# Epoch 1027/2500 | loss = 0.0023936
# Epoch 1028/2500 | loss = 0.0023282
# Epoch 1029/2500 | loss = 0.0024289
# Epoch 1030/2500 | loss = 0.0023535
# Epoch 1031/2500 | loss = 0.0022934
# Epoch 1032/2500 | loss = 0.0022865
# Epoch 1033/2500 | loss = 0.0022998
# Epoch 1034/2500 | loss = 0.0023229
# Epoch 1035/2500 | loss = 0.0023164
# Epoch 1036/2500 | loss = 0.0023732
# Epoch 1037/2500 | loss = 0.0022721
# Epoch 1038/2500 | loss = 0.0022777
# Epoch 1039/2500 | loss = 0.0023198
# Epoch 1040/2500 | loss = 0.0023029
# Epoch 1041/2500 | loss = 0.0023103
# Epoch 1042/2500 | loss = 0.0022431
# Epoch 1043/2500 | loss = 0.0022579
# Epoch 1044/2500 | loss = 0.0023335
# Epoch 1045/2500 | loss = 0.0022904
# Epoch 1046/2500 | loss = 0.0022683
# Epoch 1047/2500 | loss = 0.0023470
# Epoch 1048/2500 | loss = 0.0023373
# Epoch 1049/2500 | loss = 0.0023077
# Epoch 1050/2500 | loss = 0.0022908
# Epoch 1051/2500 | loss = 0.0023048
# Epoch 1052/2500 | loss = 0.0023017
# Epoch 1053/2500 | loss = 0.0022697
# Epoch 1054/2500 | loss = 0.0022667
# Epoch 1055/2500 | loss = 0.0022761
# Epoch 1056/2500 | loss = 0.0023336
# Epoch 1057/2500 | loss = 0.0022732
# Epoch 1058/2500 | loss = 0.0023065
# Epoch 1059/2500 | loss = 0.0023647
# Epoch 1060/2500 | loss = 0.0022553
# Epoch 1061/2500 | loss = 0.0023049
# Epoch 1062/2500 | loss = 0.0022446
# Epoch 1063/2500 | loss = 0.0022652
# Epoch 1064/2500 | loss = 0.0022357
# Epoch 1065/2500 | loss = 0.0022043
# Epoch 1066/2500 | loss = 0.0022868
# Epoch 1067/2500 | loss = 0.0022847
# Epoch 1068/2500 | loss = 0.0022830
# Epoch 1069/2500 | loss = 0.0022851
# Epoch 1070/2500 | loss = 0.0022738
# Epoch 1071/2500 | loss = 0.0023201
# Epoch 1072/2500 | loss = 0.0022903
# Epoch 1073/2500 | loss = 0.0022106
# Epoch 1074/2500 | loss = 0.0023258
# Epoch 1075/2500 | loss = 0.0022586
# Epoch 1076/2500 | loss = 0.0022880
# Epoch 1077/2500 | loss = 0.0022979
# Epoch 1078/2500 | loss = 0.0023259
# Epoch 1079/2500 | loss = 0.0022753
# Epoch 1080/2500 | loss = 0.0022582
# Epoch 1081/2500 | loss = 0.0022505
# Epoch 1082/2500 | loss = 0.0022905
# Epoch 1083/2500 | loss = 0.0022605
# Epoch 1084/2500 | loss = 0.0022534
# Epoch 1085/2500 | loss = 0.0022870
# Epoch 1086/2500 | loss = 0.0022919
# Epoch 1087/2500 | loss = 0.0023025
# Epoch 1088/2500 | loss = 0.0023229
# Epoch 1089/2500 | loss = 0.0022460
# Epoch 1090/2500 | loss = 0.0022430
# Epoch 1091/2500 | loss = 0.0022292
# Epoch 1092/2500 | loss = 0.0022795
# Epoch 1093/2500 | loss = 0.0022436
# Epoch 1094/2500 | loss = 0.0021850
# Epoch 1095/2500 | loss = 0.0022427
# Epoch 1096/2500 | loss = 0.0022523
# Epoch 1097/2500 | loss = 0.0021833
# Epoch 1098/2500 | loss = 0.0022231
# Epoch 1099/2500 | loss = 0.0021996
# Epoch 1100/2500 | loss = 0.0021873
# Epoch 1101/2500 | loss = 0.0022192
# Epoch 1102/2500 | loss = 0.0022670
# Epoch 1103/2500 | loss = 0.0022119
# Epoch 1104/2500 | loss = 0.0022441
# Epoch 1105/2500 | loss = 0.0022008
# Epoch 1106/2500 | loss = 0.0021918
# Epoch 1107/2500 | loss = 0.0022242
# Epoch 1108/2500 | loss = 0.0021827
# Epoch 1109/2500 | loss = 0.0022317
# Epoch 1110/2500 | loss = 0.0022107
# Epoch 1111/2500 | loss = 0.0022100
# Epoch 1112/2500 | loss = 0.0022859
# Epoch 1113/2500 | loss = 0.0022557
# Epoch 1114/2500 | loss = 0.0022462
# Epoch 1115/2500 | loss = 0.0022033
# Epoch 1116/2500 | loss = 0.0021733
# Epoch 1117/2500 | loss = 0.0022307
# Epoch 1118/2500 | loss = 0.0021926
# Epoch 1119/2500 | loss = 0.0022917
# Epoch 1120/2500 | loss = 0.0022504
# Epoch 1121/2500 | loss = 0.0022133
# Epoch 1122/2500 | loss = 0.0021735
# Epoch 1123/2500 | loss = 0.0022168
# Epoch 1124/2500 | loss = 0.0022604
# Epoch 1125/2500 | loss = 0.0021921
# Epoch 1126/2500 | loss = 0.0021969
# Epoch 1127/2500 | loss = 0.0022072
# Epoch 1128/2500 | loss = 0.0022266
# Epoch 1129/2500 | loss = 0.0021701
# Epoch 1130/2500 | loss = 0.0021881
# Epoch 1131/2500 | loss = 0.0021743
# Epoch 1132/2500 | loss = 0.0022588
# Epoch 1133/2500 | loss = 0.0021672
# Epoch 1134/2500 | loss = 0.0021325
# Epoch 1135/2500 | loss = 0.0021655
# Epoch 1136/2500 | loss = 0.0021606
# Epoch 1137/2500 | loss = 0.0021985
# Epoch 1138/2500 | loss = 0.0021505
# Epoch 1139/2500 | loss = 0.0022101
# Epoch 1140/2500 | loss = 0.0022008
# Epoch 1141/2500 | loss = 0.0021934
# Epoch 1142/2500 | loss = 0.0022065
# Epoch 1143/2500 | loss = 0.0021701
# Epoch 1144/2500 | loss = 0.0021877
# Epoch 1145/2500 | loss = 0.0022819
# Epoch 1146/2500 | loss = 0.0021645
# Epoch 1147/2500 | loss = 0.0022038
# Epoch 1148/2500 | loss = 0.0021809
# Epoch 1149/2500 | loss = 0.0021753
# Epoch 1150/2500 | loss = 0.0021656
# Epoch 1151/2500 | loss = 0.0021490
# Epoch 1152/2500 | loss = 0.0021695
# Epoch 1153/2500 | loss = 0.0021610
# Epoch 1154/2500 | loss = 0.0021754
# Epoch 1155/2500 | loss = 0.0022027
# Epoch 1156/2500 | loss = 0.0021579
# Epoch 1157/2500 | loss = 0.0021214
# Epoch 1158/2500 | loss = 0.0021757
# Epoch 1159/2500 | loss = 0.0021758
# Epoch 1160/2500 | loss = 0.0021884
# Epoch 1161/2500 | loss = 0.0021489
# Epoch 1162/2500 | loss = 0.0021741
# Epoch 1163/2500 | loss = 0.0021647
# Epoch 1164/2500 | loss = 0.0021313
# Epoch 1165/2500 | loss = 0.0021637
# Epoch 1166/2500 | loss = 0.0021675
# Epoch 1167/2500 | loss = 0.0021272
# Epoch 1168/2500 | loss = 0.0021556
# Epoch 1169/2500 | loss = 0.0021554
# Epoch 1170/2500 | loss = 0.0022054
# Epoch 1171/2500 | loss = 0.0021795
# Epoch 1172/2500 | loss = 0.0021784
# Epoch 1173/2500 | loss = 0.0021259
# Epoch 1174/2500 | loss = 0.0021734
# Epoch 1175/2500 | loss = 0.0021803
# Epoch 1176/2500 | loss = 0.0021294
# Epoch 1177/2500 | loss = 0.0021460
# Epoch 1178/2500 | loss = 0.0022281
# Epoch 1179/2500 | loss = 0.0021347
# Epoch 1180/2500 | loss = 0.0020881
# Epoch 1181/2500 | loss = 0.0021883
# Epoch 1182/2500 | loss = 0.0021075
# Epoch 1183/2500 | loss = 0.0021705
# Epoch 1184/2500 | loss = 0.0020784
# Epoch 1185/2500 | loss = 0.0021348
# Epoch 1186/2500 | loss = 0.0021486
# Epoch 1187/2500 | loss = 0.0021169
# Epoch 1188/2500 | loss = 0.0021564
# Epoch 1189/2500 | loss = 0.0021438
# Epoch 1190/2500 | loss = 0.0021290
# Epoch 1191/2500 | loss = 0.0021204
# Epoch 1192/2500 | loss = 0.0021722
# Epoch 1193/2500 | loss = 0.0021240
# Epoch 1194/2500 | loss = 0.0021057
# Epoch 1195/2500 | loss = 0.0020755
# Epoch 1196/2500 | loss = 0.0021137
# Epoch 1197/2500 | loss = 0.0021608
# Epoch 1198/2500 | loss = 0.0021001
# Epoch 1199/2500 | loss = 0.0020946
# Epoch 1200/2500 | loss = 0.0020799
# Epoch 1201/2500 | loss = 0.0021388
# Epoch 1202/2500 | loss = 0.0021393
# Epoch 1203/2500 | loss = 0.0020795
# Epoch 1204/2500 | loss = 0.0021329
# Epoch 1205/2500 | loss = 0.0021597
# Epoch 1206/2500 | loss = 0.0021115
# Epoch 1207/2500 | loss = 0.0021224
# Epoch 1208/2500 | loss = 0.0021370
# Epoch 1209/2500 | loss = 0.0021009
# Epoch 1210/2500 | loss = 0.0021157
# Epoch 1211/2500 | loss = 0.0021251
# Epoch 1212/2500 | loss = 0.0021212
# Epoch 1213/2500 | loss = 0.0021822
# Epoch 1214/2500 | loss = 0.0020902
# Epoch 1215/2500 | loss = 0.0020914
# Epoch 1216/2500 | loss = 0.0020633
# Epoch 1217/2500 | loss = 0.0020760
# Epoch 1218/2500 | loss = 0.0020551
# Epoch 1219/2500 | loss = 0.0021122
# Epoch 1220/2500 | loss = 0.0021249
# Epoch 1221/2500 | loss = 0.0021020
# Epoch 1222/2500 | loss = 0.0021216
# Epoch 1223/2500 | loss = 0.0020967
# Epoch 1224/2500 | loss = 0.0020639
# Epoch 1225/2500 | loss = 0.0020629
# Epoch 1226/2500 | loss = 0.0020845
# Epoch 1227/2500 | loss = 0.0020932
# Epoch 1228/2500 | loss = 0.0020749
# Epoch 1229/2500 | loss = 0.0020569
# Epoch 1230/2500 | loss = 0.0020621
# Epoch 1231/2500 | loss = 0.0021581
# Epoch 1232/2500 | loss = 0.0021419
# Epoch 1233/2500 | loss = 0.0022167
# Epoch 1234/2500 | loss = 0.0020826
# Epoch 1235/2500 | loss = 0.0021072
# Epoch 1236/2500 | loss = 0.0020605
# Epoch 1237/2500 | loss = 0.0020786
# Epoch 1238/2500 | loss = 0.0020906
# Epoch 1239/2500 | loss = 0.0020950
# Epoch 1240/2500 | loss = 0.0020726
# Epoch 1241/2500 | loss = 0.0020384
# Epoch 1242/2500 | loss = 0.0020736
# Epoch 1243/2500 | loss = 0.0020657
# Epoch 1244/2500 | loss = 0.0020804
# Epoch 1245/2500 | loss = 0.0021163
# Epoch 1246/2500 | loss = 0.0020763
# Epoch 1247/2500 | loss = 0.0020710
# Epoch 1248/2500 | loss = 0.0020334
# Epoch 1249/2500 | loss = 0.0020656
# Epoch 1250/2500 | loss = 0.0020415
# Epoch 1251/2500 | loss = 0.0020303
# Epoch 1252/2500 | loss = 0.0021293
# Epoch 1253/2500 | loss = 0.0020442
# Epoch 1254/2500 | loss = 0.0020427
# Epoch 1255/2500 | loss = 0.0021045
# Epoch 1256/2500 | loss = 0.0020788
# Epoch 1257/2500 | loss = 0.0020763
# Epoch 1258/2500 | loss = 0.0021058
# Epoch 1259/2500 | loss = 0.0020443
# Epoch 1260/2500 | loss = 0.0020136
# Epoch 1261/2500 | loss = 0.0020516
# Epoch 1262/2500 | loss = 0.0020400
# Epoch 1263/2500 | loss = 0.0020733
# Epoch 1264/2500 | loss = 0.0020435
# Epoch 1265/2500 | loss = 0.0020587
# Epoch 1266/2500 | loss = 0.0019771
# Epoch 1267/2500 | loss = 0.0020405
# Epoch 1268/2500 | loss = 0.0020019
# Epoch 1269/2500 | loss = 0.0020065
# Epoch 1270/2500 | loss = 0.0020390
# Epoch 1271/2500 | loss = 0.0020865
# Epoch 1272/2500 | loss = 0.0020441
# Epoch 1273/2500 | loss = 0.0020452
# Epoch 1274/2500 | loss = 0.0020078
# Epoch 1275/2500 | loss = 0.0020555
# Epoch 1276/2500 | loss = 0.0020662
# Epoch 1277/2500 | loss = 0.0020023
# Epoch 1278/2500 | loss = 0.0020197
# Epoch 1279/2500 | loss = 0.0020100
# Epoch 1280/2500 | loss = 0.0020338
# Epoch 1281/2500 | loss = 0.0020085
# Epoch 1282/2500 | loss = 0.0021283
# Epoch 1283/2500 | loss = 0.0021170
# Epoch 1284/2500 | loss = 0.0020628
# Epoch 1285/2500 | loss = 0.0020162
# Epoch 1286/2500 | loss = 0.0020212
# Epoch 1287/2500 | loss = 0.0020116
# Epoch 1288/2500 | loss = 0.0019987
# Epoch 1289/2500 | loss = 0.0020411
# Epoch 1290/2500 | loss = 0.0020542
# Epoch 1291/2500 | loss = 0.0019876
# Epoch 1292/2500 | loss = 0.0020076
# Epoch 1293/2500 | loss = 0.0020230
# Epoch 1294/2500 | loss = 0.0020871
# Epoch 1295/2500 | loss = 0.0020122
# Epoch 1296/2500 | loss = 0.0020062
# Epoch 1297/2500 | loss = 0.0020416
# Epoch 1298/2500 | loss = 0.0019835
# Epoch 1299/2500 | loss = 0.0019873
# Epoch 1300/2500 | loss = 0.0019971
# Epoch 1301/2500 | loss = 0.0020197
# Epoch 1302/2500 | loss = 0.0020066
# Epoch 1303/2500 | loss = 0.0020717
# Epoch 1304/2500 | loss = 0.0020568
# Epoch 1305/2500 | loss = 0.0020564
# Epoch 1306/2500 | loss = 0.0019873
# Epoch 1307/2500 | loss = 0.0019588
# Epoch 1308/2500 | loss = 0.0020142
# Epoch 1309/2500 | loss = 0.0019933
# Epoch 1310/2500 | loss = 0.0019935
# Epoch 1311/2500 | loss = 0.0019923
# Epoch 1312/2500 | loss = 0.0020338
# Epoch 1313/2500 | loss = 0.0020054
# Epoch 1314/2500 | loss = 0.0019976
# Epoch 1315/2500 | loss = 0.0020754
# Epoch 1316/2500 | loss = 0.0020204
# Epoch 1317/2500 | loss = 0.0019680
# Epoch 1318/2500 | loss = 0.0019844
# Epoch 1319/2500 | loss = 0.0019948
# Epoch 1320/2500 | loss = 0.0019547
# Epoch 1321/2500 | loss = 0.0019538
# Epoch 1322/2500 | loss = 0.0020242
# Epoch 1323/2500 | loss = 0.0020183
# Epoch 1324/2500 | loss = 0.0020024
# Epoch 1325/2500 | loss = 0.0020017
# Epoch 1326/2500 | loss = 0.0019650
# Epoch 1327/2500 | loss = 0.0019918
# Epoch 1328/2500 | loss = 0.0019668
# Epoch 1329/2500 | loss = 0.0019833
# Epoch 1330/2500 | loss = 0.0019733
# Epoch 1331/2500 | loss = 0.0019445
# Epoch 1332/2500 | loss = 0.0019946
# Epoch 1333/2500 | loss = 0.0020055
# Epoch 1334/2500 | loss = 0.0019992
# Epoch 1335/2500 | loss = 0.0019336
# Epoch 1336/2500 | loss = 0.0020103
# Epoch 1337/2500 | loss = 0.0020391
# Epoch 1338/2500 | loss = 0.0020098
# Epoch 1339/2500 | loss = 0.0020015
# Epoch 1340/2500 | loss = 0.0019465
# Epoch 1341/2500 | loss = 0.0019626
# Epoch 1342/2500 | loss = 0.0019859
# Epoch 1343/2500 | loss = 0.0019703
# Epoch 1344/2500 | loss = 0.0019750
# Epoch 1345/2500 | loss = 0.0020098
# Epoch 1346/2500 | loss = 0.0019706
# Epoch 1347/2500 | loss = 0.0019523
# Epoch 1348/2500 | loss = 0.0019491
# Epoch 1349/2500 | loss = 0.0020315
# Epoch 1350/2500 | loss = 0.0019612
# Epoch 1351/2500 | loss = 0.0019702
# Epoch 1352/2500 | loss = 0.0020124
# Epoch 1353/2500 | loss = 0.0019641
# Epoch 1354/2500 | loss = 0.0019595
# Epoch 1355/2500 | loss = 0.0019698
# Epoch 1356/2500 | loss = 0.0019709
# Epoch 1357/2500 | loss = 0.0019836
# Epoch 1358/2500 | loss = 0.0019227
# Epoch 1359/2500 | loss = 0.0019227
# Epoch 1360/2500 | loss = 0.0019541
# Epoch 1361/2500 | loss = 0.0019100
# Epoch 1362/2500 | loss = 0.0019314
# Epoch 1363/2500 | loss = 0.0019358
# Epoch 1364/2500 | loss = 0.0019783
# Epoch 1365/2500 | loss = 0.0019284
# Epoch 1366/2500 | loss = 0.0019302
# Epoch 1367/2500 | loss = 0.0019257
# Epoch 1368/2500 | loss = 0.0019531
# Epoch 1369/2500 | loss = 0.0019362
# Epoch 1370/2500 | loss = 0.0020284
# Epoch 1371/2500 | loss = 0.0019657
# Epoch 1372/2500 | loss = 0.0019547
# Epoch 1373/2500 | loss = 0.0019232
# Epoch 1374/2500 | loss = 0.0019244
# Epoch 1375/2500 | loss = 0.0019246
# Epoch 1376/2500 | loss = 0.0019144
# Epoch 1377/2500 | loss = 0.0019195
# Epoch 1378/2500 | loss = 0.0019445
# Epoch 1379/2500 | loss = 0.0019879
# Epoch 1380/2500 | loss = 0.0019218
# Epoch 1381/2500 | loss = 0.0019455
# Epoch 1382/2500 | loss = 0.0019312
# Epoch 1383/2500 | loss = 0.0020015
# Epoch 1384/2500 | loss = 0.0020388
# Epoch 1385/2500 | loss = 0.0019285
# Epoch 1386/2500 | loss = 0.0019190
# Epoch 1387/2500 | loss = 0.0019061
# Epoch 1388/2500 | loss = 0.0019117
# Epoch 1389/2500 | loss = 0.0019348
# Epoch 1390/2500 | loss = 0.0018964
# Epoch 1391/2500 | loss = 0.0019175
# Epoch 1392/2500 | loss = 0.0019377
# Epoch 1393/2500 | loss = 0.0019218
# Epoch 1394/2500 | loss = 0.0018940
# Epoch 1395/2500 | loss = 0.0019134
# Epoch 1396/2500 | loss = 0.0019582
# Epoch 1397/2500 | loss = 0.0018955
# Epoch 1398/2500 | loss = 0.0019246
# Epoch 1399/2500 | loss = 0.0019098
# Epoch 1400/2500 | loss = 0.0019074
# Epoch 1401/2500 | loss = 0.0019334
# Epoch 1402/2500 | loss = 0.0019690
# Epoch 1403/2500 | loss = 0.0019834
# ...
# Epoch 2044/2500 | loss = 0.0014766
# Epoch 2045/2500 | loss = 0.0015025
# Epoch 2046/2500 | loss = 0.0014909
# Epoch 2047/2500 | loss = 0.0014972
# Epoch 2048/2500 | loss = 0.0015163
# Epoch 2049/2500 | loss = 0.0015079
# Epoch 2050/2500 | loss = 0.0015018
# Epoch 2051/2500 | loss = 0.0014882
# Epoch 2052/2500 | loss = 0.0015406
# Epoch 2053/2500 | loss = 0.0015149
# Epoch 2054/2500 | loss = 0.0014790
# Epoch 2055/2500 | loss = 0.0014801
# Epoch 2056/2500 | loss = 0.0014676
# Epoch 2057/2500 | loss = 0.0014771
# Epoch 2058/2500 | loss = 0.0014973
# Epoch 2059/2500 | loss = 0.0014978
# Epoch 2060/2500 | loss = 0.0014848
# Epoch 2061/2500 | loss = 0.0014896
# Epoch 2062/2500 | loss = 0.0015099
# Epoch 2063/2500 | loss = 0.0014850
# Epoch 2064/2500 | loss = 0.0015017
# Epoch 2065/2500 | loss = 0.0015114
# Epoch 2066/2500 | loss = 0.0014914
# Epoch 2067/2500 | loss = 0.0014629
# Epoch 2068/2500 | loss = 0.0015120
# Epoch 2069/2500 | loss = 0.0014754
# Epoch 2070/2500 | loss = 0.0014834
# Epoch 2071/2500 | loss = 0.0014792
# Epoch 2072/2500 | loss = 0.0014940
# Epoch 2073/2500 | loss = 0.0014724
# Epoch 2074/2500 | loss = 0.0014899
# Epoch 2075/2500 | loss = 0.0014619
# Epoch 2076/2500 | loss = 0.0014930
# Epoch 2077/2500 | loss = 0.0014718
# Epoch 2078/2500 | loss = 0.0015043
# Epoch 2079/2500 | loss = 0.0014904
# Epoch 2080/2500 | loss = 0.0014892
# Epoch 2081/2500 | loss = 0.0014702
# Epoch 2082/2500 | loss = 0.0014675
# Epoch 2083/2500 | loss = 0.0014796
# Epoch 2084/2500 | loss = 0.0014702
# Epoch 2085/2500 | loss = 0.0014831
# Epoch 2086/2500 | loss = 0.0014769
# Epoch 2087/2500 | loss = 0.0015078
# Epoch 2088/2500 | loss = 0.0014795
# Epoch 2089/2500 | loss = 0.0014770
# Epoch 2090/2500 | loss = 0.0014722
# Epoch 2091/2500 | loss = 0.0014923
# Epoch 2092/2500 | loss = 0.0014944
# Epoch 2093/2500 | loss = 0.0015058
# Epoch 2094/2500 | loss = 0.0014906
# Epoch 2095/2500 | loss = 0.0014983
# Epoch 2096/2500 | loss = 0.0014737
# Epoch 2097/2500 | loss = 0.0014674
# Epoch 2098/2500 | loss = 0.0014885
# Epoch 2099/2500 | loss = 0.0014760
# Epoch 2100/2500 | loss = 0.0014771
# Epoch 2101/2500 | loss = 0.0014838
# Epoch 2102/2500 | loss = 0.0014749
# Epoch 2103/2500 | loss = 0.0014991
# Epoch 2104/2500 | loss = 0.0014515
# Epoch 2105/2500 | loss = 0.0014933
# Epoch 2106/2500 | loss = 0.0014625
# Epoch 2107/2500 | loss = 0.0014615
# Epoch 2108/2500 | loss = 0.0014683
# Epoch 2109/2500 | loss = 0.0014807
# Epoch 2110/2500 | loss = 0.0014992
# Epoch 2111/2500 | loss = 0.0014795
# Epoch 2112/2500 | loss = 0.0014952
# Epoch 2113/2500 | loss = 0.0014817
# Epoch 2114/2500 | loss = 0.0014765
# Epoch 2115/2500 | loss = 0.0014639
# Epoch 2116/2500 | loss = 0.0014780
# Epoch 2117/2500 | loss = 0.0014630
# Epoch 2118/2500 | loss = 0.0014637
# Epoch 2119/2500 | loss = 0.0014968
# Epoch 2120/2500 | loss = 0.0014850
# Epoch 2121/2500 | loss = 0.0014722
# Epoch 2122/2500 | loss = 0.0014791
# Epoch 2123/2500 | loss = 0.0014613
# Epoch 2124/2500 | loss = 0.0014584
# Epoch 2125/2500 | loss = 0.0014555
# Epoch 2126/2500 | loss = 0.0014685
# Epoch 2127/2500 | loss = 0.0014782
# Epoch 2128/2500 | loss = 0.0014786
# Epoch 2129/2500 | loss = 0.0014756
# Epoch 2130/2500 | loss = 0.0014656
# Epoch 2131/2500 | loss = 0.0014704
# Epoch 2132/2500 | loss = 0.0014651
# Epoch 2133/2500 | loss = 0.0014686
# Epoch 2134/2500 | loss = 0.0014456
# Epoch 2135/2500 | loss = 0.0014578
# Epoch 2136/2500 | loss = 0.0014648
# Epoch 2137/2500 | loss = 0.0014487
# Epoch 2138/2500 | loss = 0.0014506
# Epoch 2139/2500 | loss = 0.0014927
# Epoch 2140/2500 | loss = 0.0014367
# Epoch 2141/2500 | loss = 0.0014766
# Epoch 2142/2500 | loss = 0.0014595
# Epoch 2143/2500 | loss = 0.0014445
# Epoch 2144/2500 | loss = 0.0014570
# Epoch 2145/2500 | loss = 0.0014664
# Epoch 2146/2500 | loss = 0.0014708
# Epoch 2147/2500 | loss = 0.0014586
# Epoch 2148/2500 | loss = 0.0014551
# Epoch 2149/2500 | loss = 0.0014307
# Epoch 2150/2500 | loss = 0.0014360
# Epoch 2151/2500 | loss = 0.0014435
# Epoch 2152/2500 | loss = 0.0014277
# Epoch 2153/2500 | loss = 0.0014800
# Epoch 2154/2500 | loss = 0.0014513
# Epoch 2155/2500 | loss = 0.0014391
# Epoch 2156/2500 | loss = 0.0014385
# Epoch 2157/2500 | loss = 0.0014612
# Epoch 2158/2500 | loss = 0.0014377
# Epoch 2159/2500 | loss = 0.0014873
# Epoch 2160/2500 | loss = 0.0014461
# Epoch 2161/2500 | loss = 0.0014548
# Epoch 2162/2500 | loss = 0.0014617
# Epoch 2163/2500 | loss = 0.0014670
# Epoch 2164/2500 | loss = 0.0014321
# Epoch 2165/2500 | loss = 0.0014464
# Epoch 2166/2500 | loss = 0.0014345
# Epoch 2167/2500 | loss = 0.0014701
# Epoch 2168/2500 | loss = 0.0014486
# Epoch 2169/2500 | loss = 0.0014561
# Epoch 2170/2500 | loss = 0.0014538
# Epoch 2171/2500 | loss = 0.0014478
# Epoch 2172/2500 | loss = 0.0014519
# Epoch 2173/2500 | loss = 0.0014285
# Epoch 2174/2500 | loss = 0.0014430
# Epoch 2175/2500 | loss = 0.0014485
# Epoch 2176/2500 | loss = 0.0014349
# Epoch 2177/2500 | loss = 0.0014026
# Epoch 2178/2500 | loss = 0.0014300
# Epoch 2179/2500 | loss = 0.0014512
# Epoch 2180/2500 | loss = 0.0014525
# Epoch 2181/2500 | loss = 0.0014770
# Epoch 2182/2500 | loss = 0.0014559
# Epoch 2183/2500 | loss = 0.0014382
# Epoch 2184/2500 | loss = 0.0014520
# Epoch 2185/2500 | loss = 0.0014339
# Epoch 2186/2500 | loss = 0.0014561
# Epoch 2187/2500 | loss = 0.0014490
# Epoch 2188/2500 | loss = 0.0014189
# Epoch 2189/2500 | loss = 0.0014357
# Epoch 2190/2500 | loss = 0.0014211
# Epoch 2191/2500 | loss = 0.0014139
# Epoch 2192/2500 | loss = 0.0014224
# Epoch 2193/2500 | loss = 0.0014469
# Epoch 2194/2500 | loss = 0.0014425
# Epoch 2195/2500 | loss = 0.0014061
# Epoch 2196/2500 | loss = 0.0014313
# Epoch 2197/2500 | loss = 0.0014472
# Epoch 2198/2500 | loss = 0.0014483
# Epoch 2199/2500 | loss = 0.0014385
# Epoch 2200/2500 | loss = 0.0014414
# Epoch 2201/2500 | loss = 0.0014652
# Epoch 2202/2500 | loss = 0.0014296
# Epoch 2203/2500 | loss = 0.0014300
# Epoch 2204/2500 | loss = 0.0014233
# Epoch 2205/2500 | loss = 0.0014295
# Epoch 2206/2500 | loss = 0.0013950
# Epoch 2207/2500 | loss = 0.0014279
# Epoch 2208/2500 | loss = 0.0014238
# Epoch 2209/2500 | loss = 0.0014398
# Epoch 2210/2500 | loss = 0.0014427
# Epoch 2211/2500 | loss = 0.0014458
# Epoch 2212/2500 | loss = 0.0014446
# Epoch 2213/2500 | loss = 0.0014366
# Epoch 2214/2500 | loss = 0.0014332
# Epoch 2215/2500 | loss = 0.0014419
# Epoch 2216/2500 | loss = 0.0014274
# Epoch 2217/2500 | loss = 0.0014364
# Epoch 2218/2500 | loss = 0.0014226
# Epoch 2219/2500 | loss = 0.0014265
# Epoch 2220/2500 | loss = 0.0014559
# Epoch 2221/2500 | loss = 0.0014298
# Epoch 2222/2500 | loss = 0.0014319
# Epoch 2223/2500 | loss = 0.0014248
# Epoch 2224/2500 | loss = 0.0014057
# Epoch 2225/2500 | loss = 0.0014455
# Epoch 2226/2500 | loss = 0.0014380
# Epoch 2227/2500 | loss = 0.0014174
# Epoch 2228/2500 | loss = 0.0014382
# Epoch 2229/2500 | loss = 0.0014232
# Epoch 2230/2500 | loss = 0.0014160
# Epoch 2231/2500 | loss = 0.0014126
# Epoch 2232/2500 | loss = 0.0014495
# Epoch 2233/2500 | loss = 0.0014359
# Epoch 2234/2500 | loss = 0.0014424
# Epoch 2235/2500 | loss = 0.0014228
# Epoch 2236/2500 | loss = 0.0014295
# Epoch 2237/2500 | loss = 0.0014161
# Epoch 2238/2500 | loss = 0.0014376
# Epoch 2239/2500 | loss = 0.0014209
# Epoch 2240/2500 | loss = 0.0014320
# Epoch 2241/2500 | loss = 0.0014258
# Epoch 2242/2500 | loss = 0.0014035
# Epoch 2243/2500 | loss = 0.0014148
# Epoch 2244/2500 | loss = 0.0014362
# Epoch 2245/2500 | loss = 0.0014429
# Epoch 2246/2500 | loss = 0.0013980
# Epoch 2247/2500 | loss = 0.0014173
# Epoch 2248/2500 | loss = 0.0014481
# Epoch 2249/2500 | loss = 0.0014258
# Epoch 2250/2500 | loss = 0.0014570
# Epoch 2251/2500 | loss = 0.0014294
# Epoch 2252/2500 | loss = 0.0014350
# Epoch 2253/2500 | loss = 0.0014408
# Epoch 2254/2500 | loss = 0.0014067
# Epoch 2255/2500 | loss = 0.0014150
# Epoch 2256/2500 | loss = 0.0014107
# Epoch 2257/2500 | loss = 0.0014334
# Epoch 2258/2500 | loss = 0.0014076
# Epoch 2259/2500 | loss = 0.0014160
# Epoch 2260/2500 | loss = 0.0014133
# Epoch 2261/2500 | loss = 0.0014158
# Epoch 2262/2500 | loss = 0.0014191
# Epoch 2263/2500 | loss = 0.0014161
# Epoch 2264/2500 | loss = 0.0014207
# Epoch 2265/2500 | loss = 0.0013941
# Epoch 2266/2500 | loss = 0.0014237
# Epoch 2267/2500 | loss = 0.0014148
# Epoch 2268/2500 | loss = 0.0014492
# Epoch 2269/2500 | loss = 0.0014252
# Epoch 2270/2500 | loss = 0.0014181
# Epoch 2271/2500 | loss = 0.0013994
# Epoch 2272/2500 | loss = 0.0013933
# Epoch 2273/2500 | loss = 0.0014060
# Epoch 2274/2500 | loss = 0.0014198
# Epoch 2275/2500 | loss = 0.0014097
# Epoch 2276/2500 | loss = 0.0014078
# Epoch 2277/2500 | loss = 0.0013872
# Epoch 2278/2500 | loss = 0.0014209
# Epoch 2279/2500 | loss = 0.0014447
# Epoch 2280/2500 | loss = 0.0013946
# Epoch 2281/2500 | loss = 0.0014129
# Epoch 2282/2500 | loss = 0.0014215
# Epoch 2283/2500 | loss = 0.0014181
# Epoch 2284/2500 | loss = 0.0013870
# Epoch 2285/2500 | loss = 0.0013999
# Epoch 2286/2500 | loss = 0.0014075
# Epoch 2287/2500 | loss = 0.0014179
# Epoch 2288/2500 | loss = 0.0014037
# Epoch 2289/2500 | loss = 0.0013746
# Epoch 2290/2500 | loss = 0.0013702
# Epoch 2291/2500 | loss = 0.0014137
# Epoch 2292/2500 | loss = 0.0014201
# Epoch 2293/2500 | loss = 0.0014094
# Epoch 2294/2500 | loss = 0.0014214
# Epoch 2295/2500 | loss = 0.0014045
# Epoch 2296/2500 | loss = 0.0014100
# Epoch 2297/2500 | loss = 0.0013887
# Epoch 2298/2500 | loss = 0.0014081
# Epoch 2299/2500 | loss = 0.0014146
# Epoch 2300/2500 | loss = 0.0014118
# Epoch 2301/2500 | loss = 0.0014253
# Epoch 2302/2500 | loss = 0.0014043
# Epoch 2303/2500 | loss = 0.0014198
# Epoch 2304/2500 | loss = 0.0014146
# Epoch 2305/2500 | loss = 0.0013934
# Epoch 2306/2500 | loss = 0.0014170
# Epoch 2307/2500 | loss = 0.0013805
# Epoch 2308/2500 | loss = 0.0013953
# Epoch 2309/2500 | loss = 0.0014099
# Epoch 2310/2500 | loss = 0.0014034
# Epoch 2311/2500 | loss = 0.0013719
# Epoch 2312/2500 | loss = 0.0014033
# Epoch 2313/2500 | loss = 0.0013919
# Epoch 2314/2500 | loss = 0.0013661
# Epoch 2315/2500 | loss = 0.0014084
# Epoch 2316/2500 | loss = 0.0014120
# Epoch 2317/2500 | loss = 0.0013881
# Epoch 2318/2500 | loss = 0.0013940
# Epoch 2319/2500 | loss = 0.0013799
# Epoch 2320/2500 | loss = 0.0014067
# Epoch 2321/2500 | loss = 0.0014036
# Epoch 2322/2500 | loss = 0.0013698
# Epoch 2323/2500 | loss = 0.0014195
# Epoch 2324/2500 | loss = 0.0014187
# Epoch 2325/2500 | loss = 0.0013721
# Epoch 2326/2500 | loss = 0.0013828
# Epoch 2327/2500 | loss = 0.0013829
# Epoch 2328/2500 | loss = 0.0013737
# Epoch 2329/2500 | loss = 0.0013801
# Epoch 2330/2500 | loss = 0.0014075
# Epoch 2331/2500 | loss = 0.0014059
# Epoch 2332/2500 | loss = 0.0014163
# Epoch 2333/2500 | loss = 0.0013878
# Epoch 2334/2500 | loss = 0.0013847
# Epoch 2335/2500 | loss = 0.0014293
# Epoch 2336/2500 | loss = 0.0014005
# Epoch 2337/2500 | loss = 0.0013536
# Epoch 2338/2500 | loss = 0.0013808
# Epoch 2339/2500 | loss = 0.0013753
# Epoch 2340/2500 | loss = 0.0013913
# Epoch 2341/2500 | loss = 0.0013880
# Epoch 2342/2500 | loss = 0.0013855
# Epoch 2343/2500 | loss = 0.0014159
# Epoch 2344/2500 | loss = 0.0013885
# Epoch 2345/2500 | loss = 0.0013937
# Epoch 2346/2500 | loss = 0.0013913
# Epoch 2347/2500 | loss = 0.0013876
# Epoch 2348/2500 | loss = 0.0013738
# Epoch 2349/2500 | loss = 0.0013831
# Epoch 2350/2500 | loss = 0.0013889
# Epoch 2351/2500 | loss = 0.0013795
# Epoch 2352/2500 | loss = 0.0013935
# Epoch 2353/2500 | loss = 0.0014129
# Epoch 2354/2500 | loss = 0.0013818
# Epoch 2355/2500 | loss = 0.0013997
# Epoch 2356/2500 | loss = 0.0014009
# Epoch 2357/2500 | loss = 0.0013919
# Epoch 2358/2500 | loss = 0.0013880
# Epoch 2359/2500 | loss = 0.0014045
# Epoch 2360/2500 | loss = 0.0014266
# Epoch 2361/2500 | loss = 0.0013901
# Epoch 2362/2500 | loss = 0.0013673
# Epoch 2363/2500 | loss = 0.0013819
# Epoch 2364/2500 | loss = 0.0013775
# Epoch 2365/2500 | loss = 0.0013965
# Epoch 2366/2500 | loss = 0.0013869
# Epoch 2367/2500 | loss = 0.0013832
# Epoch 2368/2500 | loss = 0.0013640
# Epoch 2369/2500 | loss = 0.0014091
# Epoch 2370/2500 | loss = 0.0013938
# Epoch 2371/2500 | loss = 0.0013881
# Epoch 2372/2500 | loss = 0.0014363
# Epoch 2373/2500 | loss = 0.0014099
# Epoch 2374/2500 | loss = 0.0013746
# Epoch 2375/2500 | loss = 0.0013640
# Epoch 2376/2500 | loss = 0.0013994
# Epoch 2377/2500 | loss = 0.0013721
# Epoch 2378/2500 | loss = 0.0013863
# Epoch 2379/2500 | loss = 0.0013870
# Epoch 2380/2500 | loss = 0.0013668
# Epoch 2381/2500 | loss = 0.0014001
# Epoch 2382/2500 | loss = 0.0013684
# Epoch 2383/2500 | loss = 0.0013928
# Epoch 2384/2500 | loss = 0.0013396
# Epoch 2385/2500 | loss = 0.0013707
# Epoch 2386/2500 | loss = 0.0013774
# Epoch 2387/2500 | loss = 0.0013936
# Epoch 2388/2500 | loss = 0.0013485
# Epoch 2389/2500 | loss = 0.0013652
# Epoch 2390/2500 | loss = 0.0013809
# Epoch 2391/2500 | loss = 0.0013868
# Epoch 2392/2500 | loss = 0.0013820
# Epoch 2393/2500 | loss = 0.0014029
# Epoch 2394/2500 | loss = 0.0013550
# Epoch 2395/2500 | loss = 0.0013726
# Epoch 2396/2500 | loss = 0.0013673
# Epoch 2397/2500 | loss = 0.0013546
# Epoch 2398/2500 | loss = 0.0013706
# Epoch 2399/2500 | loss = 0.0013818
# Epoch 2400/2500 | loss = 0.0013831
# Epoch 2401/2500 | loss = 0.0013679
# Epoch 2402/2500 | loss = 0.0013565
# Epoch 2403/2500 | loss = 0.0013900
# Epoch 2404/2500 | loss = 0.0013914
# Epoch 2405/2500 | loss = 0.0013798
# Epoch 2406/2500 | loss = 0.0013840
# Epoch 2407/2500 | loss = 0.0013658
# Epoch 2408/2500 | loss = 0.0013635
# Epoch 2409/2500 | loss = 0.0013701
# Epoch 2410/2500 | loss = 0.0013563
# Epoch 2411/2500 | loss = 0.0013827
# Epoch 2412/2500 | loss = 0.0014026
# Epoch 2413/2500 | loss = 0.0013642
# Epoch 2414/2500 | loss = 0.0013591
# Epoch 2415/2500 | loss = 0.0013822
# Epoch 2416/2500 | loss = 0.0013883
# Epoch 2417/2500 | loss = 0.0013632
# Epoch 2418/2500 | loss = 0.0013777
# Epoch 2419/2500 | loss = 0.0013784
# Epoch 2420/2500 | loss = 0.0013682
# Epoch 2421/2500 | loss = 0.0013867
# Epoch 2422/2500 | loss = 0.0013527
# Epoch 2423/2500 | loss = 0.0013586
# Epoch 2424/2500 | loss = 0.0013776
# Epoch 2425/2500 | loss = 0.0013760
# Epoch 2426/2500 | loss = 0.0014024
# Epoch 2427/2500 | loss = 0.0013566
# Epoch 2428/2500 | loss = 0.0013963
# Epoch 2429/2500 | loss = 0.0013810
# Epoch 2430/2500 | loss = 0.0013659
# Epoch 2431/2500 | loss = 0.0013831
# Epoch 2432/2500 | loss = 0.0013664
# Epoch 2433/2500 | loss = 0.0013569
# Epoch 2434/2500 | loss = 0.0013803
# Epoch 2435/2500 | loss = 0.0013749
# Epoch 2436/2500 | loss = 0.0013724
# Epoch 2437/2500 | loss = 0.0013794
# Epoch 2438/2500 | loss = 0.0013858
# Epoch 2439/2500 | loss = 0.0013812
# Epoch 2440/2500 | loss = 0.0013928
# Epoch 2441/2500 | loss = 0.0013656
# Epoch 2442/2500 | loss = 0.0013731
# Epoch 2443/2500 | loss = 0.0014031
# Epoch 2444/2500 | loss = 0.0013989
# Epoch 2445/2500 | loss = 0.0013721
# Epoch 2446/2500 | loss = 0.0013399
# Epoch 2447/2500 | loss = 0.0013856
# Epoch 2448/2500 | loss = 0.0013570
# Epoch 2449/2500 | loss = 0.0013777
# Epoch 2450/2500 | loss = 0.0013399
# Epoch 2451/2500 | loss = 0.0013717
# Epoch 2452/2500 | loss = 0.0013838
# Epoch 2453/2500 | loss = 0.0013587
# Epoch 2454/2500 | loss = 0.0013419
# Epoch 2455/2500 | loss = 0.0013836
# Epoch 2456/2500 | loss = 0.0013559
# Epoch 2457/2500 | loss = 0.0013504
# Epoch 2458/2500 | loss = 0.0013642
# Epoch 2459/2500 | loss = 0.0013811
# Epoch 2460/2500 | loss = 0.0013678
# Epoch 2461/2500 | loss = 0.0013634
# Epoch 2462/2500 | loss = 0.0013657
# Epoch 2463/2500 | loss = 0.0013498
# Epoch 2464/2500 | loss = 0.0013942
# Epoch 2465/2500 | loss = 0.0013267
# Epoch 2466/2500 | loss = 0.0013696
# Epoch 2467/2500 | loss = 0.0014019
# Epoch 2468/2500 | loss = 0.0013753
# Epoch 2469/2500 | loss = 0.0013884
# Epoch 2470/2500 | loss = 0.0013685
# Epoch 2471/2500 | loss = 0.0013489
# Epoch 2472/2500 | loss = 0.0013846
# Epoch 2473/2500 | loss = 0.0013576
# Epoch 2474/2500 | loss = 0.0013509
# Epoch 2475/2500 | loss = 0.0013670
# Epoch 2476/2500 | loss = 0.0013402
# Epoch 2477/2500 | loss = 0.0013286
# Epoch 2478/2500 | loss = 0.0013583
# Epoch 2479/2500 | loss = 0.0013684
# Epoch 2480/2500 | loss = 0.0013727
# Epoch 2481/2500 | loss = 0.0013547
# Epoch 2482/2500 | loss = 0.0013481
# Epoch 2483/2500 | loss = 0.0013508
# Epoch 2484/2500 | loss = 0.0013610
# Epoch 2485/2500 | loss = 0.0013709
# Epoch 2486/2500 | loss = 0.0013643
# Epoch 2487/2500 | loss = 0.0013674
# Epoch 2488/2500 | loss = 0.0013796
# Epoch 2489/2500 | loss = 0.0013689
# Epoch 2490/2500 | loss = 0.0013656
# Epoch 2491/2500 | loss = 0.0013788
# Epoch 2492/2500 | loss = 0.0013745
# Epoch 2493/2500 | loss = 0.0013572
# Epoch 2494/2500 | loss = 0.0013948
# Epoch 2495/2500 | loss = 0.0013692
# Epoch 2496/2500 | loss = 0.0013788
# Epoch 2497/2500 | loss = 0.0013660
# Epoch 2498/2500 | loss = 0.0013471
# Epoch 2499/2500 | loss = 0.0013773
# Epoch 2500/2500 | loss = 0.0013749

# %%
# load trained model
checkpoint_path = '/content/drive/MyDrive/best_model_cnn.pt'
model = torch.load(checkpoint_path)
model.eval()
# Out:
# conv_autoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(3, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): Dropout(p=0.2, inplace=False)
#     (2): ReLU()
#     (3): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (4): Dropout(p=0.2, inplace=False)
#     (5): ReLU()
#     (6): Conv2d(1024, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): Dropout(p=0.2, inplace=False)
#     (8): ReLU()
#     (9): Conv2d(2048, 4096, kernel_size=(1, 1), stride=(1, 1))
#     (10): Dropout(p=0.2, inplace=False)
#     (11): ReLU()
#   )
#   (a_decoder): Sequential(
#     (0): Conv2d(4096, 2048, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#     (2): ConvTranspose2d(2048, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#     (6): ConvTranspose2d(512, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): Tanh()
#   )
#   (b_decoder): Sequential(
#     (0): Conv2d(4096, 2048, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#     (2): ConvTranspose2d(2048, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#     (6): ConvTranspose2d(512, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): Tanh()
#   )
# )

# %%
# Show images
def show_images(images):
    sqrtn = int(np.ceil(np.sqrt(images.shape[0])))
    for index, image in enumerate(images):
        plt.subplot(sqrtn, sqrtn, index+1)
        plt.imshow(transforms.ToPILImage()(image))
        plt.axis('off')

# %% [markdown]
# #Non-FaceSwap

# %%
with torch.no_grad():
  for data, target in A_train_loader:
     
        img = data.cuda()
        crop_img = crop_face(data[0]).cuda()
        output = model(torch.unsqueeze(crop_img.float(), 0), "A")

        print('Before')
        show_images(img[:16])
        plt.show()

        print('Cropped')
        plt.imshow(transforms.ToPILImage()(crop_img))
        plt.show()

        print('After')
        show_images(output[:16])
        plt.show()
        break

with torch.no_grad():
  for data, target in B_train_loader:
    
        img = data.cuda()
        crop_img = crop_face(data[0]).cuda()
        output = model(torch.unsqueeze(crop_img.float(), 0), "B")

        print('Before')
        show_images(img[:16])
        plt.show()

        print('Cropped')
        plt.imshow(transforms.ToPILImage()(crop_img))
        plt.show()

        print('After')
        show_images(output[:16])
        plt.show()
        break
# Out:
# Before
# Cropped
# After
# Before
# Cropped
# After

# %% [markdown]
# #FaceSwap

# %%
with torch.no_grad():
  for data, target in A_train_loader:
     
        img = data.cuda()
        crop_img = crop_face(data[0]).cuda()
        output = model(torch.unsqueeze(crop_img.float(), 0), "B")

        print('Before')
        show_images(img[:16])
        plt.show()

        print('Cropped')
        plt.imshow(transforms.ToPILImage()(crop_img))
        plt.show()

        print('After')
        show_images(output[:16])
        plt.show()
        break

with torch.no_grad():
  for data, target in B_train_loader:
    
        img = data.cuda()
        crop_img = crop_face(data[0]).cuda()
        output = model(torch.unsqueeze(crop_img.float(), 0), "A")

        print('Before')
        show_images(img[:16])
        plt.show()

        print('Cropped')
        plt.imshow(transforms.ToPILImage()(crop_img))
        plt.show()

        print('After')
        show_images(output[:16])
        plt.show()
        break
# Out:
# Before
# Cropped
# After
# Before
# Cropped
# After
